# %%
import argparse
import logging
import sys
import os
import random
import json
from pathlib import Path
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.utils.data.dataset import random_split

from advertorch.attacks import LinfPGDAttack, GradientSignAttack

from model_robustness.attacks.networks import ConvNetLarge, ConvNetSmall

ROOT = Path("")

# %% [markdown]
# # 1. Setup

# %%
# loading in the SVHN zoo
checkpoint_path = ROOT.joinpath("/netscratch2/dtaskiran/zoos/SVHN/tune_zoo_svhn_hyperparameter_10_fixed_seeds")
data_root = ROOT.joinpath("/netscratch2/jlautz/model_robustness/src/model_robustness/data/SVHN")
data_path = checkpoint_path.joinpath("dataset.pt")
zoo_path = ROOT.joinpath("/netscratch2/dtaskiran/zoos/SVHN/analysis_data_hyp_fix.pt")

# %%
# Load in the data
dataset = torch.load(data_path)["testset"]

# %%
# Define some parameters
config = {}
config["dataset"] = "SVHN"
config["attack"] = "FGSM"
config["setup"] = "hyp-10-f"
config["eps"] = 0.1
config["nb_iter"] = 10
config["eps_iter"] = config["eps"]/10
config["device"] = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load in the zoo to see which model was the best performing one
zoo = torch.load(zoo_path)

# %%
# Get the best performing model from zoo

# Getting only the 50th epoch's results
a = 0
index_list = [50]
path_list = []
for i in range(len(zoo["paths"])):
    if i == 0:
        aux = zoo["paths"][i]
        path_list.append(zoo["paths"][i])
    
    if zoo["paths"][i] == aux:
        pass
    else: 
        a +=1 
        index_list.append(i+50)
        aux = zoo["paths"][i]
        path_list.append(aux)
        
for i in range(len(path_list)):
    path_list[i] = path_list[i].__str__().split("/")[-1]

# Get all accuracies
acc_list = []
for index in index_list:
    acc_list.append(zoo["acc"][index])
    
# Get the index of max element 
max_index = acc_list.index(max(acc_list))

# Get the corresponding model name
best_model_path = path_list[max_index]

# %%
# Load in the best model

model_config_path = os.path.join(checkpoint_path, best_model_path, "params.json")
config_model = json.load(open(model_config_path, ))

model = ConvNetSmall(
    channels_in=config_model["model::channels_in"],
    nlin=config_model["model::nlin"],
    dropout=config_model["model::dropout"],
    init_type=config_model["model::init_type"]
)

try:
    model.load_state_dict(
        torch.load(os.path.join(checkpoint_path, best_model_path, "checkpoint_000050", "checkpoints"))
    )
except RuntimeError:
    model = ConvNetSmall(
        channels_in=config_model["model::channels_in"],
        nlin=config_model["model::nlin"],
        dropout=0,
        init_type=config_model["model::init_type"]
    )
    model.load_state_dict(
        torch.load(os.path.join(checkpoint_path, best_model_path, "checkpoint_000050", "checkpoints"))
    )
    
model.to(config["device"])
# Out:
# ConvNetSmall(
#   (module_list): ModuleList(
#     (0): Conv2d(1, 8, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(8, 6, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(6, 4, kernel_size=(2, 2), stride=(1, 1))
#     (7): ReLU()
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=36, out_features=20, bias=True)
#     (10): ReLU()
#     (11): Linear(in_features=20, out_features=10, bias=True)
#   )
# )

# %%
# Attack
aux_loader = DataLoader(
    dataset=dataset, 
    batch_size=len(dataset),
    shuffle=False
)

for cln_data, true_labels in aux_loader:
    break
cln_data, true_labels = cln_data.to(config["device"]), true_labels.to(config["device"])

if config["attack"] == "PGD":
    adversary = LinfPGDAttack(
        model,
        loss_fn=nn.CrossEntropyLoss(reduction="sum"),
        eps=config["eps"],
        nb_iter=config["nb_iter"],
        eps_iter=config["eps_iter"],
        rand_init=False,
        clip_min=0.0,
        clip_max=1.0,
        targeted=False
    )
elif config["attack"] == "FGSM":
    adversary = GradientSignAttack(
        model,
        loss_fn=nn.CrossEntropyLoss(reduction="sum"),
        eps=config["eps"],
        targeted=False
    )
else:
    raise NotImplementedError("error: attack type unknown")

# %%
# Perturb images
adv_images = adversary.perturb(cln_data, true_labels)

adv_data = torch.utils.data.TensorDataset(adv_images, true_labels)

# %%
# Define dataloader for evaluation
loader = DataLoader(
    dataset=dataset,
    batch_size=config_model["training::batchsize"],
    shuffle=False
)

# Define criterion and optimizer
if config_model["optim::optimizer"] == "sgd":
    optimizer = optim.SGD(model.parameters(), lr=config_model["optim::lr"], 
        momentum=config_model["optim::momentum"], weight_decay=config_model["optim::wd"])

elif config_model["optim::optimizer"] == "adam":
    optimizer = optim.Adam(model.parameters(), lr=config_model["optim::lr"], 
        weight_decay=config_model["optim::wd"])
    
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # 2. Normal Performance

# %%
# Evaluate        
loss_avg, acc_avg, num_exp = 0, 0, 0

for j, data in enumerate(loader):
            
    model.eval()

    imgs, labels = data
    labels = labels.type(torch.LongTensor)
    imgs, labels = imgs.to(config["device"]), labels.to(config["device"])
    n_b = labels.shape[0]

    outputs = model(imgs)
    loss = criterion(outputs, labels)

    acc = np.sum(np.equal(np.argmax(outputs.cpu().data.numpy(), axis=-1),
        labels.cpu().data.numpy()))

    loss_avg += loss.item()
    acc_avg += acc
    num_exp += n_b

loss_avg /= num_exp
acc_avg /= num_exp

# %%
print(loss_avg, acc_avg)
# Out:
# 0.05028887705163476 0.8524124154886293

# %% [markdown]
# # 3. White Box

# %%
# Define dataloader for evaluation
perturbed_loader = DataLoader(
    dataset=adv_data,
    batch_size=config_model["training::batchsize"],
    shuffle=False
)

# %%
# Evaluate        
loss_avg, acc_avg, num_exp = 0, 0, 0

for j, data in enumerate(perturbed_loader):
            
    model.eval()

    imgs, labels = data
    labels = labels.type(torch.LongTensor)
    imgs, labels = imgs.to(config["device"]), labels.to(config["device"])
    n_b = labels.shape[0]

    outputs = model(imgs)
    loss = criterion(outputs, labels)

    acc = np.sum(np.equal(np.argmax(outputs.cpu().data.numpy(), axis=-1),
        labels.cpu().data.numpy()))

    loss_avg += loss.item()
    acc_avg += acc
    num_exp += n_b

loss_avg /= num_exp
acc_avg /= num_exp

# %%
print(loss_avg, acc_avg)
# Out:
# 0.3188218671849115 0.20444068838352797

# %% [markdown]
# # 3. Black Box 1: only knowledge of training data

# %%
# Save config of source model
source_config = config_model

# %%
# Deleting source model from list
del path_list[max_index]

# %%
df = pd.read_csv("../../data/all_results.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               name dataset  \
# 0           0  NN_tune_trainable_a17ed_00710_710_model::dropo...   MNIST
# 1           1  NN_tune_trainable_a17ed_00686_686_model::dropo...   MNIST
# 2           2  NN_tune_trainable_a17ed_01002_1002_model::drop...   MNIST
# 3           3  NN_tune_trainable_a17ed_00775_775_model::dropo...   MNIST
# 4           4  NN_tune_trainable_a17ed_01098_1098_model::drop...   MNIST
#
#   attack     setup  eps  dropout       init_type  nlin      lr  momentum  \
# 0    PGD  hyp-10-r  0.1      0.0  kaiming_normal  tanh  0.0010       0.9
# 1    PGD  hyp-10-r  0.1      0.0  kaiming_normal  relu  0.0001       0.9
# 2    PGD  hyp-10-r  0.1      0.0          normal  relu  0.0001       0.9
# 3    PGD  hyp-10-r  0.1      0.5  kaiming_normal  tanh  0.0010       0.9
# 4    PGD  hyp-10-r  0.1      0.0          normal  relu  0.0010       0.9
#
#   optimizer      wd    seed  old_loss  old_acc  new_loss  new_acc
# 0       sgd  0.0001  674695     0.067    0.979  0.378464   0.3051
# 1      adam  0.0001  486815     0.054    0.984  0.056045   0.8454
# 2       sgd  0.0001  162638     2.301    0.113  0.230108   0.1135
# 3      adam  0.0010  651635     0.134    0.960  0.296555   0.2168
# 4       sgd  0.0010  361619     2.301    0.113  0.230111   0.1135

# %%
temp = df[df.attack=="FGSM"]
temp = temp[temp.dataset=="SVHN"]
temp = temp[temp.setup=="hyp-10-f"]

# %%
temp.optimizer.value_counts()
# Out:
# sgd    21600
# Name: optimizer, dtype: int64

# %%
for i, path in enumerate(path_list):
    print(f"checking model {i} of {len(path_list)}")
    # Read in config containing the paramters for the i-th model
    model_config_path = os.path.join(checkpoint_path, path, "params.json")
    config_model = json.load(open(model_config_path, ))
    
    # Only read in models that have a different initialization and activation function and optimizer
#     if config_model["model::nlin"] == source_config["model::nlin"]:
#         print(config_model["model::nlin"])
#         continue
#     elif config_model["model::init_type"] == source_config["model::init_type"]:
#         print(config_model["model::init_type"])
#         continue
#     elif config_model["optim::optimizer"] == source_config["optim::optimizer"]:
#         print(config_model["optim::optimizer"])
#         continue
    
    if config_model["model::nlin"] != source_config["model::nlin"] and config_model["model::init_type"] != source_config["model::init_type"]:
        print("success")
    else:
        continue
    
    # Define model and load in state
    model = ConvNetSmall(
        channels_in=config_model["model::channels_in"],
        nlin=config_model["model::nlin"],
        dropout=config_model["model::dropout"],
        init_type=config_model["model::init_type"]
    )
    try:
        model.load_state_dict(
            torch.load(os.path.join(checkpoint_path, path, "checkpoint_000050", "checkpoints"))
        )
    except RuntimeError:
        model = ConvNetSmall(
            channels_in=config_model["model::channels_in"],
            nlin=config_model["model::nlin"],
            dropout=0,
            init_type=config_model["model::init_type"]
        )
        model.load_state_dict(
            torch.load(os.path.join(checkpoint_path, path, "checkpoint_000050", "checkpoints"))
        )
    model.to(config["device"])
    break
# Out:
# checking model 0 of 4319
# success

# %%
# Evaluate        
loss_avg, acc_avg, num_exp = 0, 0, 0

for j, data in enumerate(perturbed_loader):
            
    model.eval()

    imgs, labels = data
    labels = labels.type(torch.LongTensor)
    imgs, labels = imgs.to(config["device"]), labels.to(config["device"])
    n_b = labels.shape[0]

    outputs = model(imgs)
    loss = criterion(outputs, labels)

    acc = np.sum(np.equal(np.argmax(outputs.cpu().data.numpy(), axis=-1),
        labels.cpu().data.numpy()))

    loss_avg += loss.item()
    acc_avg += acc
    num_exp += n_b
    print(f"Batch {j} of {len(adv_data)/source_config['training::batchsize']} done.")
    
loss_avg /= num_exp
acc_avg /= num_exp
# Out:
# Batch 0 of 2603.2 done.
# Batch 1 of 2603.2 done.
# Batch 2 of 2603.2 done.
# Batch 3 of 2603.2 done.
# Batch 4 of 2603.2 done.
# Batch 5 of 2603.2 done.
# Batch 6 of 2603.2 done.
# Batch 7 of 2603.2 done.
# Batch 8 of 2603.2 done.
# Batch 9 of 2603.2 done.
# Batch 10 of 2603.2 done.
# Batch 11 of 2603.2 done.
# Batch 12 of 2603.2 done.
# Batch 13 of 2603.2 done.
# Batch 14 of 2603.2 done.
# Batch 15 of 2603.2 done.
# Batch 16 of 2603.2 done.
# Batch 17 of 2603.2 done.
# Batch 18 of 2603.2 done.
# Batch 19 of 2603.2 done.
# Batch 20 of 2603.2 done.
# Batch 21 of 2603.2 done.
# Batch 22 of 2603.2 done.
# Batch 23 of 2603.2 done.
# Batch 24 of 2603.2 done.
# Batch 25 of 2603.2 done.
# Batch 26 of 2603.2 done.
# Batch 27 of 2603.2 done.
# Batch 28 of 2603.2 done.
# Batch 29 of 2603.2 done.
# Batch 30 of 2603.2 done.
# Batch 31 of 2603.2 done.
# Batch 32 of 2603.2 done.
# Batch 33 of 2603.2 done.
# Batch 34 of 2603.2 done.
# Batch 35 of 2603.2 done.
# Batch 36 of 2603.2 done.
# Batch 37 of 2603.2 done.
# Batch 38 of 2603.2 done.
# Batch 39 of 2603.2 done.
# Batch 40 of 2603.2 done.
# Batch 41 of 2603.2 done.
# Batch 42 of 2603.2 done.
# Batch 43 of 2603.2 done.
# Batch 44 of 2603.2 done.
# Batch 45 of 2603.2 done.
# Batch 46 of 2603.2 done.
# Batch 47 of 2603.2 done.
# Batch 48 of 2603.2 done.
# Batch 49 of 2603.2 done.
# Batch 50 of 2603.2 done.
# Batch 51 of 2603.2 done.
# Batch 52 of 2603.2 done.
# Batch 53 of 2603.2 done.
# Batch 54 of 2603.2 done.
# Batch 55 of 2603.2 done.
# Batch 56 of 2603.2 done.
# Batch 57 of 2603.2 done.
# Batch 58 of 2603.2 done.
# Batch 59 of 2603.2 done.
# Batch 60 of 2603.2 done.
# Batch 61 of 2603.2 done.
# Batch 62 of 2603.2 done.
# Batch 63 of 2603.2 done.
# Batch 64 of 2603.2 done.
# Batch 65 of 2603.2 done.
# Batch 66 of 2603.2 done.
# Batch 67 of 2603.2 done.
# Batch 68 of 2603.2 done.
# Batch 69 of 2603.2 done.
# Batch 70 of 2603.2 done.
# Batch 71 of 2603.2 done.
# Batch 72 of 2603.2 done.
# Batch 73 of 2603.2 done.
# Batch 74 of 2603.2 done.
# Batch 75 of 2603.2 done.
# Batch 76 of 2603.2 done.
# Batch 77 of 2603.2 done.
# Batch 78 of 2603.2 done.
# Batch 79 of 2603.2 done.
# Batch 80 of 2603.2 done.
# Batch 81 of 2603.2 done.
# Batch 82 of 2603.2 done.
# Batch 83 of 2603.2 done.
# Batch 84 of 2603.2 done.
# Batch 85 of 2603.2 done.
# Batch 86 of 2603.2 done.
# Batch 87 of 2603.2 done.
# Batch 88 of 2603.2 done.
# Batch 89 of 2603.2 done.
# Batch 90 of 2603.2 done.
# Batch 91 of 2603.2 done.
# Batch 92 of 2603.2 done.
# Batch 93 of 2603.2 done.
# Batch 94 of 2603.2 done.
# Batch 95 of 2603.2 done.
# Batch 96 of 2603.2 done.
# Batch 97 of 2603.2 done.
# Batch 98 of 2603.2 done.
# Batch 99 of 2603.2 done.
# Batch 100 of 2603.2 done.
# Batch 101 of 2603.2 done.
# Batch 102 of 2603.2 done.
# Batch 103 of 2603.2 done.
# Batch 104 of 2603.2 done.
# Batch 105 of 2603.2 done.
# Batch 106 of 2603.2 done.
# Batch 107 of 2603.2 done.
# Batch 108 of 2603.2 done.
# Batch 109 of 2603.2 done.
# Batch 110 of 2603.2 done.
# Batch 111 of 2603.2 done.
# Batch 112 of 2603.2 done.
# Batch 113 of 2603.2 done.
# Batch 114 of 2603.2 done.
# Batch 115 of 2603.2 done.
# Batch 116 of 2603.2 done.
# Batch 117 of 2603.2 done.
# Batch 118 of 2603.2 done.
# Batch 119 of 2603.2 done.
# Batch 120 of 2603.2 done.
# Batch 121 of 2603.2 done.
# Batch 122 of 2603.2 done.
# Batch 123 of 2603.2 done.
# Batch 124 of 2603.2 done.
# Batch 125 of 2603.2 done.
# Batch 126 of 2603.2 done.
# Batch 127 of 2603.2 done.
# Batch 128 of 2603.2 done.
# Batch 129 of 2603.2 done.
# Batch 130 of 2603.2 done.
# Batch 131 of 2603.2 done.
# Batch 132 of 2603.2 done.
# Batch 133 of 2603.2 done.
# Batch 134 of 2603.2 done.
# Batch 135 of 2603.2 done.
# Batch 136 of 2603.2 done.
# Batch 137 of 2603.2 done.
# Batch 138 of 2603.2 done.
# Batch 139 of 2603.2 done.
# Batch 140 of 2603.2 done.
# Batch 141 of 2603.2 done.
# Batch 142 of 2603.2 done.
# Batch 143 of 2603.2 done.
# Batch 144 of 2603.2 done.
# Batch 145 of 2603.2 done.
# Batch 146 of 2603.2 done.
# Batch 147 of 2603.2 done.
# Batch 148 of 2603.2 done.
# Batch 149 of 2603.2 done.
# Batch 150 of 2603.2 done.
# Batch 151 of 2603.2 done.
# Batch 152 of 2603.2 done.
# Batch 153 of 2603.2 done.
# Batch 154 of 2603.2 done.
# Batch 155 of 2603.2 done.
# Batch 156 of 2603.2 done.
# Batch 157 of 2603.2 done.
# Batch 158 of 2603.2 done.
# Batch 159 of 2603.2 done.
# Batch 160 of 2603.2 done.
# Batch 161 of 2603.2 done.
# Batch 162 of 2603.2 done.
# Batch 163 of 2603.2 done.
# Batch 164 of 2603.2 done.
# Batch 165 of 2603.2 done.
# Batch 166 of 2603.2 done.
# Batch 167 of 2603.2 done.
# Batch 168 of 2603.2 done.
# Batch 169 of 2603.2 done.
# Batch 170 of 2603.2 done.
# Batch 171 of 2603.2 done.
# Batch 172 of 2603.2 done.
# Batch 173 of 2603.2 done.
# Batch 174 of 2603.2 done.
# Batch 175 of 2603.2 done.
# Batch 176 of 2603.2 done.
# Batch 177 of 2603.2 done.
# Batch 178 of 2603.2 done.
# Batch 179 of 2603.2 done.
# Batch 180 of 2603.2 done.
# Batch 181 of 2603.2 done.
# Batch 182 of 2603.2 done.
# Batch 183 of 2603.2 done.
# Batch 184 of 2603.2 done.
# Batch 185 of 2603.2 done.
# Batch 186 of 2603.2 done.
# Batch 187 of 2603.2 done.
# Batch 188 of 2603.2 done.
# Batch 189 of 2603.2 done.
# Batch 190 of 2603.2 done.
# Batch 191 of 2603.2 done.
# Batch 192 of 2603.2 done.
# Batch 193 of 2603.2 done.
# Batch 194 of 2603.2 done.
# Batch 195 of 2603.2 done.
# Batch 196 of 2603.2 done.
# Batch 197 of 2603.2 done.
# Batch 198 of 2603.2 done.
# Batch 199 of 2603.2 done.
# Batch 200 of 2603.2 done.
# Batch 201 of 2603.2 done.
# Batch 202 of 2603.2 done.
# Batch 203 of 2603.2 done.
# Batch 204 of 2603.2 done.
# Batch 205 of 2603.2 done.
# Batch 206 of 2603.2 done.
# Batch 207 of 2603.2 done.
# Batch 208 of 2603.2 done.
# Batch 209 of 2603.2 done.
# Batch 210 of 2603.2 done.
# Batch 211 of 2603.2 done.
# Batch 212 of 2603.2 done.
# Batch 213 of 2603.2 done.
# Batch 214 of 2603.2 done.
# Batch 215 of 2603.2 done.
# Batch 216 of 2603.2 done.
# Batch 217 of 2603.2 done.
# Batch 218 of 2603.2 done.
# Batch 219 of 2603.2 done.
# Batch 220 of 2603.2 done.
# Batch 221 of 2603.2 done.
# Batch 222 of 2603.2 done.
# Batch 223 of 2603.2 done.
# Batch 224 of 2603.2 done.
# Batch 225 of 2603.2 done.
# Batch 226 of 2603.2 done.
# Batch 227 of 2603.2 done.
# Batch 228 of 2603.2 done.
# Batch 229 of 2603.2 done.
# Batch 230 of 2603.2 done.
# Batch 231 of 2603.2 done.
# Batch 232 of 2603.2 done.
# Batch 233 of 2603.2 done.
# Batch 234 of 2603.2 done.
# Batch 235 of 2603.2 done.
# Batch 236 of 2603.2 done.
# Batch 237 of 2603.2 done.
# Batch 238 of 2603.2 done.
# Batch 239 of 2603.2 done.
# Batch 240 of 2603.2 done.
# Batch 241 of 2603.2 done.
# Batch 242 of 2603.2 done.
# Batch 243 of 2603.2 done.
# Batch 244 of 2603.2 done.
# Batch 245 of 2603.2 done.
# Batch 246 of 2603.2 done.
# Batch 247 of 2603.2 done.
# Batch 248 of 2603.2 done.
# Batch 249 of 2603.2 done.
# Batch 250 of 2603.2 done.
# Batch 251 of 2603.2 done.
# Batch 252 of 2603.2 done.
# Batch 253 of 2603.2 done.
# Batch 254 of 2603.2 done.
# Batch 255 of 2603.2 done.
# Batch 256 of 2603.2 done.
# Batch 257 of 2603.2 done.
# Batch 258 of 2603.2 done.
# Batch 259 of 2603.2 done.
# Batch 260 of 2603.2 done.
# Batch 261 of 2603.2 done.
# Batch 262 of 2603.2 done.
# Batch 263 of 2603.2 done.
# Batch 264 of 2603.2 done.
# Batch 265 of 2603.2 done.
# Batch 266 of 2603.2 done.
# Batch 267 of 2603.2 done.
# Batch 268 of 2603.2 done.
# Batch 269 of 2603.2 done.
# Batch 270 of 2603.2 done.
# Batch 271 of 2603.2 done.
# Batch 272 of 2603.2 done.
# Batch 273 of 2603.2 done.
# Batch 274 of 2603.2 done.
# Batch 275 of 2603.2 done.
# Batch 276 of 2603.2 done.
# Batch 277 of 2603.2 done.
# Batch 278 of 2603.2 done.
# Batch 279 of 2603.2 done.
# Batch 280 of 2603.2 done.
# Batch 281 of 2603.2 done.
# Batch 282 of 2603.2 done.
# Batch 283 of 2603.2 done.
# Batch 284 of 2603.2 done.
# Batch 285 of 2603.2 done.
# Batch 286 of 2603.2 done.
# Batch 287 of 2603.2 done.
# Batch 288 of 2603.2 done.
# Batch 289 of 2603.2 done.
# Batch 290 of 2603.2 done.
# Batch 291 of 2603.2 done.
# Batch 292 of 2603.2 done.
# Batch 293 of 2603.2 done.
# Batch 294 of 2603.2 done.
# Batch 295 of 2603.2 done.
# Batch 296 of 2603.2 done.
# Batch 297 of 2603.2 done.
# Batch 298 of 2603.2 done.
# Batch 299 of 2603.2 done.
# Batch 300 of 2603.2 done.
# Batch 301 of 2603.2 done.
# Batch 302 of 2603.2 done.
# Batch 303 of 2603.2 done.
# Batch 304 of 2603.2 done.
# Batch 305 of 2603.2 done.
# Batch 306 of 2603.2 done.
# Batch 307 of 2603.2 done.
# Batch 308 of 2603.2 done.
# Batch 309 of 2603.2 done.
# Batch 310 of 2603.2 done.
# Batch 311 of 2603.2 done.
# Batch 312 of 2603.2 done.
# Batch 313 of 2603.2 done.
# Batch 314 of 2603.2 done.
# Batch 315 of 2603.2 done.
# Batch 316 of 2603.2 done.
# Batch 317 of 2603.2 done.
# Batch 318 of 2603.2 done.
# Batch 319 of 2603.2 done.
# Batch 320 of 2603.2 done.
# Batch 321 of 2603.2 done.
# Batch 322 of 2603.2 done.
# Batch 323 of 2603.2 done.
# Batch 324 of 2603.2 done.
# Batch 325 of 2603.2 done.
# Batch 326 of 2603.2 done.
# Batch 327 of 2603.2 done.
# Batch 328 of 2603.2 done.
# Batch 329 of 2603.2 done.
# Batch 330 of 2603.2 done.
# Batch 331 of 2603.2 done.
# Batch 332 of 2603.2 done.
# Batch 333 of 2603.2 done.
# Batch 334 of 2603.2 done.
# Batch 335 of 2603.2 done.
# Batch 336 of 2603.2 done.
# Batch 337 of 2603.2 done.
# Batch 338 of 2603.2 done.
# Batch 339 of 2603.2 done.
# Batch 340 of 2603.2 done.
# Batch 341 of 2603.2 done.
# Batch 342 of 2603.2 done.
# Batch 343 of 2603.2 done.
# Batch 344 of 2603.2 done.
# Batch 345 of 2603.2 done.
# Batch 346 of 2603.2 done.
# Batch 347 of 2603.2 done.
# Batch 348 of 2603.2 done.
# Batch 349 of 2603.2 done.
# Batch 350 of 2603.2 done.
# Batch 351 of 2603.2 done.
# Batch 352 of 2603.2 done.
# Batch 353 of 2603.2 done.
# Batch 354 of 2603.2 done.
# Batch 355 of 2603.2 done.
# Batch 356 of 2603.2 done.
# Batch 357 of 2603.2 done.
# Batch 358 of 2603.2 done.
# Batch 359 of 2603.2 done.
# Batch 360 of 2603.2 done.
# Batch 361 of 2603.2 done.
# Batch 362 of 2603.2 done.
# Batch 363 of 2603.2 done.
# Batch 364 of 2603.2 done.
# Batch 365 of 2603.2 done.
# Batch 366 of 2603.2 done.
# Batch 367 of 2603.2 done.
# Batch 368 of 2603.2 done.
# Batch 369 of 2603.2 done.
# Batch 370 of 2603.2 done.
# Batch 371 of 2603.2 done.
# Batch 372 of 2603.2 done.
# Batch 373 of 2603.2 done.
# Batch 374 of 2603.2 done.
# Batch 375 of 2603.2 done.
# Batch 376 of 2603.2 done.
# Batch 377 of 2603.2 done.
# Batch 378 of 2603.2 done.
# Batch 379 of 2603.2 done.
# Batch 380 of 2603.2 done.
# Batch 381 of 2603.2 done.
# Batch 382 of 2603.2 done.
# Batch 383 of 2603.2 done.
# Batch 384 of 2603.2 done.
# Batch 385 of 2603.2 done.
# Batch 386 of 2603.2 done.
# Batch 387 of 2603.2 done.
# Batch 388 of 2603.2 done.
# Batch 389 of 2603.2 done.
# Batch 390 of 2603.2 done.
# Batch 391 of 2603.2 done.
# Batch 392 of 2603.2 done.
# Batch 393 of 2603.2 done.
# Batch 394 of 2603.2 done.
# Batch 395 of 2603.2 done.
# Batch 396 of 2603.2 done.
# Batch 397 of 2603.2 done.
# Batch 398 of 2603.2 done.
# Batch 399 of 2603.2 done.
# Batch 400 of 2603.2 done.
# Batch 401 of 2603.2 done.
# Batch 402 of 2603.2 done.
# Batch 403 of 2603.2 done.
# Batch 404 of 2603.2 done.
# Batch 405 of 2603.2 done.
# Batch 406 of 2603.2 done.
# Batch 407 of 2603.2 done.
# Batch 408 of 2603.2 done.
# Batch 409 of 2603.2 done.
# Batch 410 of 2603.2 done.
# Batch 411 of 2603.2 done.
# Batch 412 of 2603.2 done.
# Batch 413 of 2603.2 done.
# Batch 414 of 2603.2 done.
# Batch 415 of 2603.2 done.
# Batch 416 of 2603.2 done.
# Batch 417 of 2603.2 done.
# Batch 418 of 2603.2 done.
# Batch 419 of 2603.2 done.
# Batch 420 of 2603.2 done.
# Batch 421 of 2603.2 done.
# Batch 422 of 2603.2 done.
# Batch 423 of 2603.2 done.
# Batch 424 of 2603.2 done.
# Batch 425 of 2603.2 done.
# Batch 426 of 2603.2 done.
# Batch 427 of 2603.2 done.
# Batch 428 of 2603.2 done.
# Batch 429 of 2603.2 done.
# Batch 430 of 2603.2 done.
# Batch 431 of 2603.2 done.
# Batch 432 of 2603.2 done.
# Batch 433 of 2603.2 done.
# Batch 434 of 2603.2 done.
# Batch 435 of 2603.2 done.
# Batch 436 of 2603.2 done.
# Batch 437 of 2603.2 done.
# Batch 438 of 2603.2 done.
# Batch 439 of 2603.2 done.
# Batch 440 of 2603.2 done.
# Batch 441 of 2603.2 done.
# Batch 442 of 2603.2 done.
# Batch 443 of 2603.2 done.
# Batch 444 of 2603.2 done.
# Batch 445 of 2603.2 done.
# Batch 446 of 2603.2 done.
# Batch 447 of 2603.2 done.
# Batch 448 of 2603.2 done.
# Batch 449 of 2603.2 done.
# Batch 450 of 2603.2 done.
# Batch 451 of 2603.2 done.
# Batch 452 of 2603.2 done.
# Batch 453 of 2603.2 done.
# Batch 454 of 2603.2 done.
# Batch 455 of 2603.2 done.
# Batch 456 of 2603.2 done.
# Batch 457 of 2603.2 done.
# Batch 458 of 2603.2 done.
# Batch 459 of 2603.2 done.
# Batch 460 of 2603.2 done.
# Batch 461 of 2603.2 done.
# Batch 462 of 2603.2 done.
# Batch 463 of 2603.2 done.
# Batch 464 of 2603.2 done.
# Batch 465 of 2603.2 done.
# Batch 466 of 2603.2 done.
# Batch 467 of 2603.2 done.
# Batch 468 of 2603.2 done.
# Batch 469 of 2603.2 done.
# Batch 470 of 2603.2 done.
# Batch 471 of 2603.2 done.
# Batch 472 of 2603.2 done.
# Batch 473 of 2603.2 done.
# Batch 474 of 2603.2 done.
# Batch 475 of 2603.2 done.
# Batch 476 of 2603.2 done.
# Batch 477 of 2603.2 done.
# Batch 478 of 2603.2 done.
# Batch 479 of 2603.2 done.
# Batch 480 of 2603.2 done.
# Batch 481 of 2603.2 done.
# Batch 482 of 2603.2 done.
# Batch 483 of 2603.2 done.
# Batch 484 of 2603.2 done.
# Batch 485 of 2603.2 done.
# Batch 486 of 2603.2 done.
# Batch 487 of 2603.2 done.
# Batch 488 of 2603.2 done.
# Batch 489 of 2603.2 done.
# Batch 490 of 2603.2 done.
# Batch 491 of 2603.2 done.
# Batch 492 of 2603.2 done.
# Batch 493 of 2603.2 done.
# Batch 494 of 2603.2 done.
# Batch 495 of 2603.2 done.
# Batch 496 of 2603.2 done.
# Batch 497 of 2603.2 done.
# Batch 498 of 2603.2 done.
# Batch 499 of 2603.2 done.
# Batch 500 of 2603.2 done.
# Batch 501 of 2603.2 done.
# Batch 502 of 2603.2 done.
# Batch 503 of 2603.2 done.
# Batch 504 of 2603.2 done.
# Batch 505 of 2603.2 done.
# Batch 506 of 2603.2 done.
# Batch 507 of 2603.2 done.
# Batch 508 of 2603.2 done.
# Batch 509 of 2603.2 done.
# Batch 510 of 2603.2 done.
# Batch 511 of 2603.2 done.
# Batch 512 of 2603.2 done.
# Batch 513 of 2603.2 done.
# Batch 514 of 2603.2 done.
# Batch 515 of 2603.2 done.
# Batch 516 of 2603.2 done.
# Batch 517 of 2603.2 done.
# Batch 518 of 2603.2 done.
# Batch 519 of 2603.2 done.
# Batch 520 of 2603.2 done.
# Batch 521 of 2603.2 done.
# Batch 522 of 2603.2 done.
# Batch 523 of 2603.2 done.
# Batch 524 of 2603.2 done.
# Batch 525 of 2603.2 done.
# Batch 526 of 2603.2 done.
# Batch 527 of 2603.2 done.
# Batch 528 of 2603.2 done.
# Batch 529 of 2603.2 done.
# Batch 530 of 2603.2 done.
# Batch 531 of 2603.2 done.
# Batch 532 of 2603.2 done.
# Batch 533 of 2603.2 done.
# Batch 534 of 2603.2 done.
# Batch 535 of 2603.2 done.
# Batch 536 of 2603.2 done.
# Batch 537 of 2603.2 done.
# Batch 538 of 2603.2 done.
# Batch 539 of 2603.2 done.
# Batch 540 of 2603.2 done.
# Batch 541 of 2603.2 done.
# Batch 542 of 2603.2 done.
# Batch 543 of 2603.2 done.
# Batch 544 of 2603.2 done.
# Batch 545 of 2603.2 done.
# Batch 546 of 2603.2 done.
# Batch 547 of 2603.2 done.
# Batch 548 of 2603.2 done.
# Batch 549 of 2603.2 done.
# Batch 550 of 2603.2 done.
# Batch 551 of 2603.2 done.
# Batch 552 of 2603.2 done.
# Batch 553 of 2603.2 done.
# Batch 554 of 2603.2 done.
# Batch 555 of 2603.2 done.
# Batch 556 of 2603.2 done.
# Batch 557 of 2603.2 done.
# Batch 558 of 2603.2 done.
# Batch 559 of 2603.2 done.
# Batch 560 of 2603.2 done.
# Batch 561 of 2603.2 done.
# Batch 562 of 2603.2 done.
# Batch 563 of 2603.2 done.
# Batch 564 of 2603.2 done.
# Batch 565 of 2603.2 done.
# Batch 566 of 2603.2 done.
# Batch 567 of 2603.2 done.
# Batch 568 of 2603.2 done.
# Batch 569 of 2603.2 done.
# Batch 570 of 2603.2 done.
# Batch 571 of 2603.2 done.
# Batch 572 of 2603.2 done.
# Batch 573 of 2603.2 done.
# Batch 574 of 2603.2 done.
# Batch 575 of 2603.2 done.
# Batch 576 of 2603.2 done.
# Batch 577 of 2603.2 done.
# Batch 578 of 2603.2 done.
# Batch 579 of 2603.2 done.
# Batch 580 of 2603.2 done.
# Batch 581 of 2603.2 done.
# Batch 582 of 2603.2 done.
# Batch 583 of 2603.2 done.
# Batch 584 of 2603.2 done.
# Batch 585 of 2603.2 done.
# Batch 586 of 2603.2 done.
# Batch 587 of 2603.2 done.
# Batch 588 of 2603.2 done.
# Batch 589 of 2603.2 done.
# Batch 590 of 2603.2 done.
# Batch 591 of 2603.2 done.
# Batch 592 of 2603.2 done.
# Batch 593 of 2603.2 done.
# Batch 594 of 2603.2 done.
# Batch 595 of 2603.2 done.
# Batch 596 of 2603.2 done.
# Batch 597 of 2603.2 done.
# Batch 598 of 2603.2 done.
# Batch 599 of 2603.2 done.
# Batch 600 of 2603.2 done.
# Batch 601 of 2603.2 done.
# Batch 602 of 2603.2 done.
# Batch 603 of 2603.2 done.
# Batch 604 of 2603.2 done.
# Batch 605 of 2603.2 done.
# Batch 606 of 2603.2 done.
# Batch 607 of 2603.2 done.
# Batch 608 of 2603.2 done.
# Batch 609 of 2603.2 done.
# Batch 610 of 2603.2 done.
# Batch 611 of 2603.2 done.
# Batch 612 of 2603.2 done.
# Batch 613 of 2603.2 done.
# Batch 614 of 2603.2 done.
# Batch 615 of 2603.2 done.
# Batch 616 of 2603.2 done.
# Batch 617 of 2603.2 done.
# Batch 618 of 2603.2 done.
# Batch 619 of 2603.2 done.
# Batch 620 of 2603.2 done.
# Batch 621 of 2603.2 done.
# Batch 622 of 2603.2 done.
# Batch 623 of 2603.2 done.
# Batch 624 of 2603.2 done.
# Batch 625 of 2603.2 done.
# Batch 626 of 2603.2 done.
# Batch 627 of 2603.2 done.
# Batch 628 of 2603.2 done.
# Batch 629 of 2603.2 done.
# Batch 630 of 2603.2 done.
# Batch 631 of 2603.2 done.
# Batch 632 of 2603.2 done.
# Batch 633 of 2603.2 done.
# Batch 634 of 2603.2 done.
# Batch 635 of 2603.2 done.
# Batch 636 of 2603.2 done.
# Batch 637 of 2603.2 done.
# Batch 638 of 2603.2 done.
# Batch 639 of 2603.2 done.
# Batch 640 of 2603.2 done.
# Batch 641 of 2603.2 done.
# Batch 642 of 2603.2 done.
# Batch 643 of 2603.2 done.
# Batch 644 of 2603.2 done.
# Batch 645 of 2603.2 done.
# Batch 646 of 2603.2 done.
# Batch 647 of 2603.2 done.
# Batch 648 of 2603.2 done.
# Batch 649 of 2603.2 done.
# Batch 650 of 2603.2 done.
# Batch 651 of 2603.2 done.
# Batch 652 of 2603.2 done.
# Batch 653 of 2603.2 done.
# Batch 654 of 2603.2 done.
# Batch 655 of 2603.2 done.
# Batch 656 of 2603.2 done.
# Batch 657 of 2603.2 done.
# Batch 658 of 2603.2 done.
# Batch 659 of 2603.2 done.
# Batch 660 of 2603.2 done.
# Batch 661 of 2603.2 done.
# Batch 662 of 2603.2 done.
# Batch 663 of 2603.2 done.
# Batch 664 of 2603.2 done.
# Batch 665 of 2603.2 done.
# Batch 666 of 2603.2 done.
# Batch 667 of 2603.2 done.
# Batch 668 of 2603.2 done.
# Batch 669 of 2603.2 done.
# Batch 670 of 2603.2 done.
# Batch 671 of 2603.2 done.
# Batch 672 of 2603.2 done.
# Batch 673 of 2603.2 done.
# Batch 674 of 2603.2 done.
# Batch 675 of 2603.2 done.
# Batch 676 of 2603.2 done.
# Batch 677 of 2603.2 done.
# Batch 678 of 2603.2 done.
# Batch 679 of 2603.2 done.
# Batch 680 of 2603.2 done.
# Batch 681 of 2603.2 done.
# Batch 682 of 2603.2 done.
# Batch 683 of 2603.2 done.
# Batch 684 of 2603.2 done.
# Batch 685 of 2603.2 done.
# Batch 686 of 2603.2 done.
# Batch 687 of 2603.2 done.
# Batch 688 of 2603.2 done.
# Batch 689 of 2603.2 done.
# Batch 690 of 2603.2 done.
# Batch 691 of 2603.2 done.
# Batch 692 of 2603.2 done.
# Batch 693 of 2603.2 done.
# Batch 694 of 2603.2 done.
# Batch 695 of 2603.2 done.
# Batch 696 of 2603.2 done.
# Batch 697 of 2603.2 done.
# Batch 698 of 2603.2 done.
# Batch 699 of 2603.2 done.
# Batch 700 of 2603.2 done.
# Batch 701 of 2603.2 done.
# Batch 702 of 2603.2 done.
# Batch 703 of 2603.2 done.
# Batch 704 of 2603.2 done.
# Batch 705 of 2603.2 done.
# Batch 706 of 2603.2 done.
# Batch 707 of 2603.2 done.
# Batch 708 of 2603.2 done.
# Batch 709 of 2603.2 done.
# Batch 710 of 2603.2 done.
# Batch 711 of 2603.2 done.
# Batch 712 of 2603.2 done.
# Batch 713 of 2603.2 done.
# Batch 714 of 2603.2 done.
# Batch 715 of 2603.2 done.
# Batch 716 of 2603.2 done.
# Batch 717 of 2603.2 done.
# Batch 718 of 2603.2 done.
# Batch 719 of 2603.2 done.
# Batch 720 of 2603.2 done.
# Batch 721 of 2603.2 done.
# Batch 722 of 2603.2 done.
# Batch 723 of 2603.2 done.
# Batch 724 of 2603.2 done.
# Batch 725 of 2603.2 done.
# Batch 726 of 2603.2 done.
# Batch 727 of 2603.2 done.
# Batch 728 of 2603.2 done.
# Batch 729 of 2603.2 done.
# Batch 730 of 2603.2 done.
# Batch 731 of 2603.2 done.
# Batch 732 of 2603.2 done.
# Batch 733 of 2603.2 done.
# Batch 734 of 2603.2 done.
# Batch 735 of 2603.2 done.
# Batch 736 of 2603.2 done.
# Batch 737 of 2603.2 done.
# Batch 738 of 2603.2 done.
# Batch 739 of 2603.2 done.
# Batch 740 of 2603.2 done.
# Batch 741 of 2603.2 done.
# Batch 742 of 2603.2 done.
# Batch 743 of 2603.2 done.
# Batch 744 of 2603.2 done.
# Batch 745 of 2603.2 done.
# Batch 746 of 2603.2 done.
# Batch 747 of 2603.2 done.
# Batch 748 of 2603.2 done.
# Batch 749 of 2603.2 done.
# Batch 750 of 2603.2 done.
# Batch 751 of 2603.2 done.
# Batch 752 of 2603.2 done.
# Batch 753 of 2603.2 done.
# Batch 754 of 2603.2 done.
# Batch 755 of 2603.2 done.
# Batch 756 of 2603.2 done.
# Batch 757 of 2603.2 done.
# Batch 758 of 2603.2 done.
# Batch 759 of 2603.2 done.
# Batch 760 of 2603.2 done.
# Batch 761 of 2603.2 done.
# Batch 762 of 2603.2 done.
# Batch 763 of 2603.2 done.
# Batch 764 of 2603.2 done.
# Batch 765 of 2603.2 done.
# Batch 766 of 2603.2 done.
# Batch 767 of 2603.2 done.
# Batch 768 of 2603.2 done.
# Batch 769 of 2603.2 done.
# Batch 770 of 2603.2 done.
# Batch 771 of 2603.2 done.
# Batch 772 of 2603.2 done.
# Batch 773 of 2603.2 done.
# Batch 774 of 2603.2 done.
# Batch 775 of 2603.2 done.
# Batch 776 of 2603.2 done.
# Batch 777 of 2603.2 done.
# Batch 778 of 2603.2 done.
# Batch 779 of 2603.2 done.
# Batch 780 of 2603.2 done.
# Batch 781 of 2603.2 done.
# Batch 782 of 2603.2 done.
# Batch 783 of 2603.2 done.
# Batch 784 of 2603.2 done.
# Batch 785 of 2603.2 done.
# Batch 786 of 2603.2 done.
# Batch 787 of 2603.2 done.
# Batch 788 of 2603.2 done.
# Batch 789 of 2603.2 done.
# Batch 790 of 2603.2 done.
# Batch 791 of 2603.2 done.
# Batch 792 of 2603.2 done.
# Batch 793 of 2603.2 done.
# Batch 794 of 2603.2 done.
# Batch 795 of 2603.2 done.
# Batch 796 of 2603.2 done.
# Batch 797 of 2603.2 done.
# Batch 798 of 2603.2 done.
# Batch 799 of 2603.2 done.
# Batch 800 of 2603.2 done.
# Batch 801 of 2603.2 done.
# Batch 802 of 2603.2 done.
# Batch 803 of 2603.2 done.
# Batch 804 of 2603.2 done.
# Batch 805 of 2603.2 done.
# Batch 806 of 2603.2 done.
# Batch 807 of 2603.2 done.
# Batch 808 of 2603.2 done.
# Batch 809 of 2603.2 done.
# Batch 810 of 2603.2 done.
# Batch 811 of 2603.2 done.
# Batch 812 of 2603.2 done.
# Batch 813 of 2603.2 done.
# Batch 814 of 2603.2 done.
# Batch 815 of 2603.2 done.
# Batch 816 of 2603.2 done.
# Batch 817 of 2603.2 done.
# Batch 818 of 2603.2 done.
# Batch 819 of 2603.2 done.
# Batch 820 of 2603.2 done.
# Batch 821 of 2603.2 done.
# Batch 822 of 2603.2 done.
# Batch 823 of 2603.2 done.
# Batch 824 of 2603.2 done.
# Batch 825 of 2603.2 done.
# Batch 826 of 2603.2 done.
# Batch 827 of 2603.2 done.
# Batch 828 of 2603.2 done.
# Batch 829 of 2603.2 done.
# Batch 830 of 2603.2 done.
# Batch 831 of 2603.2 done.
# Batch 832 of 2603.2 done.
# Batch 833 of 2603.2 done.
# Batch 834 of 2603.2 done.
# Batch 835 of 2603.2 done.
# Batch 836 of 2603.2 done.
# Batch 837 of 2603.2 done.
# Batch 838 of 2603.2 done.
# Batch 839 of 2603.2 done.
# Batch 840 of 2603.2 done.
# Batch 841 of 2603.2 done.
# Batch 842 of 2603.2 done.
# Batch 843 of 2603.2 done.
# Batch 844 of 2603.2 done.
# Batch 845 of 2603.2 done.
# Batch 846 of 2603.2 done.
# Batch 847 of 2603.2 done.
# Batch 848 of 2603.2 done.
# Batch 849 of 2603.2 done.
# Batch 850 of 2603.2 done.
# Batch 851 of 2603.2 done.
# Batch 852 of 2603.2 done.
# Batch 853 of 2603.2 done.
# Batch 854 of 2603.2 done.
# Batch 855 of 2603.2 done.
# Batch 856 of 2603.2 done.
# Batch 857 of 2603.2 done.
# Batch 858 of 2603.2 done.
# Batch 859 of 2603.2 done.
# Batch 860 of 2603.2 done.
# Batch 861 of 2603.2 done.
# Batch 862 of 2603.2 done.
# Batch 863 of 2603.2 done.
# Batch 864 of 2603.2 done.
# Batch 865 of 2603.2 done.
# Batch 866 of 2603.2 done.
# Batch 867 of 2603.2 done.
# Batch 868 of 2603.2 done.
# Batch 869 of 2603.2 done.
# Batch 870 of 2603.2 done.
# Batch 871 of 2603.2 done.
# Batch 872 of 2603.2 done.
# Batch 873 of 2603.2 done.
# Batch 874 of 2603.2 done.
# Batch 875 of 2603.2 done.
# Batch 876 of 2603.2 done.
# Batch 877 of 2603.2 done.
# Batch 878 of 2603.2 done.
# Batch 879 of 2603.2 done.
# Batch 880 of 2603.2 done.
# Batch 881 of 2603.2 done.
# Batch 882 of 2603.2 done.
# Batch 883 of 2603.2 done.
# Batch 884 of 2603.2 done.
# Batch 885 of 2603.2 done.
# Batch 886 of 2603.2 done.
# Batch 887 of 2603.2 done.
# Batch 888 of 2603.2 done.
# Batch 889 of 2603.2 done.
# Batch 890 of 2603.2 done.
# Batch 891 of 2603.2 done.
# Batch 892 of 2603.2 done.
# Batch 893 of 2603.2 done.
# Batch 894 of 2603.2 done.
# Batch 895 of 2603.2 done.
# Batch 896 of 2603.2 done.
# Batch 897 of 2603.2 done.
# Batch 898 of 2603.2 done.
# Batch 899 of 2603.2 done.
# Batch 900 of 2603.2 done.
# Batch 901 of 2603.2 done.
# Batch 902 of 2603.2 done.
# Batch 903 of 2603.2 done.
# Batch 904 of 2603.2 done.
# Batch 905 of 2603.2 done.
# Batch 906 of 2603.2 done.
# Batch 907 of 2603.2 done.
# Batch 908 of 2603.2 done.
# Batch 909 of 2603.2 done.
# Batch 910 of 2603.2 done.
# Batch 911 of 2603.2 done.
# Batch 912 of 2603.2 done.
# Batch 913 of 2603.2 done.
# Batch 914 of 2603.2 done.
# Batch 915 of 2603.2 done.
# Batch 916 of 2603.2 done.
# Batch 917 of 2603.2 done.
# Batch 918 of 2603.2 done.
# Batch 919 of 2603.2 done.
# Batch 920 of 2603.2 done.
# Batch 921 of 2603.2 done.
# Batch 922 of 2603.2 done.
# Batch 923 of 2603.2 done.
# Batch 924 of 2603.2 done.
# Batch 925 of 2603.2 done.
# Batch 926 of 2603.2 done.
# Batch 927 of 2603.2 done.
# Batch 928 of 2603.2 done.
# Batch 929 of 2603.2 done.
# Batch 930 of 2603.2 done.
# Batch 931 of 2603.2 done.
# Batch 932 of 2603.2 done.
# Batch 933 of 2603.2 done.
# Batch 934 of 2603.2 done.
# Batch 935 of 2603.2 done.
# Batch 936 of 2603.2 done.
# Batch 937 of 2603.2 done.
# Batch 938 of 2603.2 done.
# Batch 939 of 2603.2 done.
# Batch 940 of 2603.2 done.
# Batch 941 of 2603.2 done.
# Batch 942 of 2603.2 done.
# Batch 943 of 2603.2 done.
# Batch 944 of 2603.2 done.
# Batch 945 of 2603.2 done.
# Batch 946 of 2603.2 done.
# Batch 947 of 2603.2 done.
# Batch 948 of 2603.2 done.
# Batch 949 of 2603.2 done.
# Batch 950 of 2603.2 done.
# Batch 951 of 2603.2 done.
# Batch 952 of 2603.2 done.
# Batch 953 of 2603.2 done.
# Batch 954 of 2603.2 done.
# Batch 955 of 2603.2 done.
# Batch 956 of 2603.2 done.
# Batch 957 of 2603.2 done.
# Batch 958 of 2603.2 done.
# Batch 959 of 2603.2 done.
# Batch 960 of 2603.2 done.
# Batch 961 of 2603.2 done.
# Batch 962 of 2603.2 done.
# Batch 963 of 2603.2 done.
# Batch 964 of 2603.2 done.
# Batch 965 of 2603.2 done.
# Batch 966 of 2603.2 done.
# Batch 967 of 2603.2 done.
# Batch 968 of 2603.2 done.
# Batch 969 of 2603.2 done.
# Batch 970 of 2603.2 done.
# Batch 971 of 2603.2 done.
# Batch 972 of 2603.2 done.
# Batch 973 of 2603.2 done.
# Batch 974 of 2603.2 done.
# Batch 975 of 2603.2 done.
# Batch 976 of 2603.2 done.
# Batch 977 of 2603.2 done.
# Batch 978 of 2603.2 done.
# Batch 979 of 2603.2 done.
# Batch 980 of 2603.2 done.
# Batch 981 of 2603.2 done.
# Batch 982 of 2603.2 done.
# Batch 983 of 2603.2 done.
# Batch 984 of 2603.2 done.
# Batch 985 of 2603.2 done.
# Batch 986 of 2603.2 done.
# Batch 987 of 2603.2 done.
# Batch 988 of 2603.2 done.
# Batch 989 of 2603.2 done.
# Batch 990 of 2603.2 done.
# Batch 991 of 2603.2 done.
# Batch 992 of 2603.2 done.
# Batch 993 of 2603.2 done.
# Batch 994 of 2603.2 done.
# Batch 995 of 2603.2 done.
# Batch 996 of 2603.2 done.
# Batch 997 of 2603.2 done.
# Batch 998 of 2603.2 done.
# Batch 999 of 2603.2 done.
# Batch 1000 of 2603.2 done.
# Batch 1001 of 2603.2 done.
# Batch 1002 of 2603.2 done.
# Batch 1003 of 2603.2 done.
# Batch 1004 of 2603.2 done.
# Batch 1005 of 2603.2 done.
# Batch 1006 of 2603.2 done.
# Batch 1007 of 2603.2 done.
# Batch 1008 of 2603.2 done.
# Batch 1009 of 2603.2 done.
# Batch 1010 of 2603.2 done.
# Batch 1011 of 2603.2 done.
# Batch 1012 of 2603.2 done.
# Batch 1013 of 2603.2 done.
# Batch 1014 of 2603.2 done.
# Batch 1015 of 2603.2 done.
# Batch 1016 of 2603.2 done.
# Batch 1017 of 2603.2 done.
# Batch 1018 of 2603.2 done.
# Batch 1019 of 2603.2 done.
# Batch 1020 of 2603.2 done.
# Batch 1021 of 2603.2 done.
# Batch 1022 of 2603.2 done.
# Batch 1023 of 2603.2 done.
# Batch 1024 of 2603.2 done.
# Batch 1025 of 2603.2 done.
# Batch 1026 of 2603.2 done.
# Batch 1027 of 2603.2 done.
# Batch 1028 of 2603.2 done.
# Batch 1029 of 2603.2 done.
# Batch 1030 of 2603.2 done.
# Batch 1031 of 2603.2 done.
# Batch 1032 of 2603.2 done.
# Batch 1033 of 2603.2 done.
# Batch 1034 of 2603.2 done.
# Batch 1035 of 2603.2 done.
# Batch 1036 of 2603.2 done.
# Batch 1037 of 2603.2 done.
# Batch 1038 of 2603.2 done.
# Batch 1039 of 2603.2 done.
# Batch 1040 of 2603.2 done.
# Batch 1041 of 2603.2 done.
# Batch 1042 of 2603.2 done.
# Batch 1043 of 2603.2 done.
# Batch 1044 of 2603.2 done.
# Batch 1045 of 2603.2 done.
# Batch 1046 of 2603.2 done.
# Batch 1047 of 2603.2 done.
# Batch 1048 of 2603.2 done.
# Batch 1049 of 2603.2 done.
# Batch 1050 of 2603.2 done.
# Batch 1051 of 2603.2 done.
# Batch 1052 of 2603.2 done.
# Batch 1053 of 2603.2 done.
# Batch 1054 of 2603.2 done.
# Batch 1055 of 2603.2 done.
# Batch 1056 of 2603.2 done.
# Batch 1057 of 2603.2 done.
# Batch 1058 of 2603.2 done.
# Batch 1059 of 2603.2 done.
# Batch 1060 of 2603.2 done.
# Batch 1061 of 2603.2 done.
# Batch 1062 of 2603.2 done.
# Batch 1063 of 2603.2 done.
# Batch 1064 of 2603.2 done.
# Batch 1065 of 2603.2 done.
# Batch 1066 of 2603.2 done.
# Batch 1067 of 2603.2 done.
# Batch 1068 of 2603.2 done.
# Batch 1069 of 2603.2 done.
# Batch 1070 of 2603.2 done.
# Batch 1071 of 2603.2 done.
# Batch 1072 of 2603.2 done.
# Batch 1073 of 2603.2 done.
# Batch 1074 of 2603.2 done.
# Batch 1075 of 2603.2 done.
# Batch 1076 of 2603.2 done.
# Batch 1077 of 2603.2 done.
# Batch 1078 of 2603.2 done.
# Batch 1079 of 2603.2 done.
# Batch 1080 of 2603.2 done.
# Batch 1081 of 2603.2 done.
# Batch 1082 of 2603.2 done.
# Batch 1083 of 2603.2 done.
# Batch 1084 of 2603.2 done.
# Batch 1085 of 2603.2 done.
# Batch 1086 of 2603.2 done.
# Batch 1087 of 2603.2 done.
# Batch 1088 of 2603.2 done.
# Batch 1089 of 2603.2 done.
# Batch 1090 of 2603.2 done.
# Batch 1091 of 2603.2 done.
# Batch 1092 of 2603.2 done.
# Batch 1093 of 2603.2 done.
# Batch 1094 of 2603.2 done.
# Batch 1095 of 2603.2 done.
# Batch 1096 of 2603.2 done.
# Batch 1097 of 2603.2 done.
# Batch 1098 of 2603.2 done.
# Batch 1099 of 2603.2 done.
# Batch 1100 of 2603.2 done.
# Batch 1101 of 2603.2 done.
# Batch 1102 of 2603.2 done.
# Batch 1103 of 2603.2 done.
# Batch 1104 of 2603.2 done.
# Batch 1105 of 2603.2 done.
# Batch 1106 of 2603.2 done.
# Batch 1107 of 2603.2 done.
# Batch 1108 of 2603.2 done.
# Batch 1109 of 2603.2 done.
# Batch 1110 of 2603.2 done.
# Batch 1111 of 2603.2 done.
# Batch 1112 of 2603.2 done.
# Batch 1113 of 2603.2 done.
# Batch 1114 of 2603.2 done.
# Batch 1115 of 2603.2 done.
# Batch 1116 of 2603.2 done.
# Batch 1117 of 2603.2 done.
# Batch 1118 of 2603.2 done.
# Batch 1119 of 2603.2 done.
# Batch 1120 of 2603.2 done.
# Batch 1121 of 2603.2 done.
# Batch 1122 of 2603.2 done.
# Batch 1123 of 2603.2 done.
# Batch 1124 of 2603.2 done.
# Batch 1125 of 2603.2 done.
# Batch 1126 of 2603.2 done.
# Batch 1127 of 2603.2 done.
# Batch 1128 of 2603.2 done.
# Batch 1129 of 2603.2 done.
# Batch 1130 of 2603.2 done.
# Batch 1131 of 2603.2 done.
# Batch 1132 of 2603.2 done.
# Batch 1133 of 2603.2 done.
# Batch 1134 of 2603.2 done.
# Batch 1135 of 2603.2 done.
# Batch 1136 of 2603.2 done.
# Batch 1137 of 2603.2 done.
# Batch 1138 of 2603.2 done.
# Batch 1139 of 2603.2 done.
# Batch 1140 of 2603.2 done.
# Batch 1141 of 2603.2 done.
# Batch 1142 of 2603.2 done.
# Batch 1143 of 2603.2 done.
# Batch 1144 of 2603.2 done.
# Batch 1145 of 2603.2 done.
# Batch 1146 of 2603.2 done.
# Batch 1147 of 2603.2 done.
# Batch 1148 of 2603.2 done.
# Batch 1149 of 2603.2 done.
# Batch 1150 of 2603.2 done.
# Batch 1151 of 2603.2 done.
# Batch 1152 of 2603.2 done.
# Batch 1153 of 2603.2 done.
# Batch 1154 of 2603.2 done.
# Batch 1155 of 2603.2 done.
# Batch 1156 of 2603.2 done.
# Batch 1157 of 2603.2 done.
# Batch 1158 of 2603.2 done.
# Batch 1159 of 2603.2 done.
# Batch 1160 of 2603.2 done.
# Batch 1161 of 2603.2 done.
# Batch 1162 of 2603.2 done.
# Batch 1163 of 2603.2 done.
# Batch 1164 of 2603.2 done.
# Batch 1165 of 2603.2 done.
# Batch 1166 of 2603.2 done.
# Batch 1167 of 2603.2 done.
# Batch 1168 of 2603.2 done.
# Batch 1169 of 2603.2 done.
# Batch 1170 of 2603.2 done.
# Batch 1171 of 2603.2 done.
# Batch 1172 of 2603.2 done.
# Batch 1173 of 2603.2 done.
# Batch 1174 of 2603.2 done.
# Batch 1175 of 2603.2 done.
# Batch 1176 of 2603.2 done.
# Batch 1177 of 2603.2 done.
# Batch 1178 of 2603.2 done.
# Batch 1179 of 2603.2 done.
# Batch 1180 of 2603.2 done.
# Batch 1181 of 2603.2 done.
# Batch 1182 of 2603.2 done.
# Batch 1183 of 2603.2 done.
# Batch 1184 of 2603.2 done.
# Batch 1185 of 2603.2 done.
# Batch 1186 of 2603.2 done.
# Batch 1187 of 2603.2 done.
# Batch 1188 of 2603.2 done.
# Batch 1189 of 2603.2 done.
# Batch 1190 of 2603.2 done.
# Batch 1191 of 2603.2 done.
# Batch 1192 of 2603.2 done.
# Batch 1193 of 2603.2 done.
# Batch 1194 of 2603.2 done.
# Batch 1195 of 2603.2 done.
# Batch 1196 of 2603.2 done.
# Batch 1197 of 2603.2 done.
# Batch 1198 of 2603.2 done.
# Batch 1199 of 2603.2 done.
# Batch 1200 of 2603.2 done.
# Batch 1201 of 2603.2 done.
# Batch 1202 of 2603.2 done.
# Batch 1203 of 2603.2 done.
# Batch 1204 of 2603.2 done.
# Batch 1205 of 2603.2 done.
# Batch 1206 of 2603.2 done.
# Batch 1207 of 2603.2 done.
# Batch 1208 of 2603.2 done.
# Batch 1209 of 2603.2 done.
# Batch 1210 of 2603.2 done.
# Batch 1211 of 2603.2 done.
# Batch 1212 of 2603.2 done.
# Batch 1213 of 2603.2 done.
# Batch 1214 of 2603.2 done.
# Batch 1215 of 2603.2 done.
# Batch 1216 of 2603.2 done.
# Batch 1217 of 2603.2 done.
# Batch 1218 of 2603.2 done.
# Batch 1219 of 2603.2 done.
# Batch 1220 of 2603.2 done.
# Batch 1221 of 2603.2 done.
# Batch 1222 of 2603.2 done.
# Batch 1223 of 2603.2 done.
# Batch 1224 of 2603.2 done.
# Batch 1225 of 2603.2 done.
# Batch 1226 of 2603.2 done.
# Batch 1227 of 2603.2 done.
# Batch 1228 of 2603.2 done.
# Batch 1229 of 2603.2 done.
# Batch 1230 of 2603.2 done.
# Batch 1231 of 2603.2 done.
# Batch 1232 of 2603.2 done.
# Batch 1233 of 2603.2 done.
# Batch 1234 of 2603.2 done.
# Batch 1235 of 2603.2 done.
# Batch 1236 of 2603.2 done.
# Batch 1237 of 2603.2 done.
# Batch 1238 of 2603.2 done.
# Batch 1239 of 2603.2 done.
# Batch 1240 of 2603.2 done.
# Batch 1241 of 2603.2 done.
# Batch 1242 of 2603.2 done.
# Batch 1243 of 2603.2 done.
# Batch 1244 of 2603.2 done.
# Batch 1245 of 2603.2 done.
# Batch 1246 of 2603.2 done.
# Batch 1247 of 2603.2 done.
# Batch 1248 of 2603.2 done.
# Batch 1249 of 2603.2 done.
# Batch 1250 of 2603.2 done.
# Batch 1251 of 2603.2 done.
# Batch 1252 of 2603.2 done.
# Batch 1253 of 2603.2 done.
# Batch 1254 of 2603.2 done.
# Batch 1255 of 2603.2 done.
# Batch 1256 of 2603.2 done.
# Batch 1257 of 2603.2 done.
# Batch 1258 of 2603.2 done.
# Batch 1259 of 2603.2 done.
# Batch 1260 of 2603.2 done.
# Batch 1261 of 2603.2 done.
# Batch 1262 of 2603.2 done.
# Batch 1263 of 2603.2 done.
# Batch 1264 of 2603.2 done.
# Batch 1265 of 2603.2 done.
# Batch 1266 of 2603.2 done.
# Batch 1267 of 2603.2 done.
# Batch 1268 of 2603.2 done.
# Batch 1269 of 2603.2 done.
# Batch 1270 of 2603.2 done.
# Batch 1271 of 2603.2 done.
# Batch 1272 of 2603.2 done.
# Batch 1273 of 2603.2 done.
# Batch 1274 of 2603.2 done.
# Batch 1275 of 2603.2 done.
# Batch 1276 of 2603.2 done.
# Batch 1277 of 2603.2 done.
# Batch 1278 of 2603.2 done.
# Batch 1279 of 2603.2 done.
# Batch 1280 of 2603.2 done.
# Batch 1281 of 2603.2 done.
# Batch 1282 of 2603.2 done.
# Batch 1283 of 2603.2 done.
# Batch 1284 of 2603.2 done.
# Batch 1285 of 2603.2 done.
# Batch 1286 of 2603.2 done.
# Batch 1287 of 2603.2 done.
# Batch 1288 of 2603.2 done.
# Batch 1289 of 2603.2 done.
# Batch 1290 of 2603.2 done.
# Batch 1291 of 2603.2 done.
# Batch 1292 of 2603.2 done.
# Batch 1293 of 2603.2 done.
# Batch 1294 of 2603.2 done.
# Batch 1295 of 2603.2 done.
# Batch 1296 of 2603.2 done.
# Batch 1297 of 2603.2 done.
# Batch 1298 of 2603.2 done.
# Batch 1299 of 2603.2 done.
# Batch 1300 of 2603.2 done.
# Batch 1301 of 2603.2 done.
# Batch 1302 of 2603.2 done.
# Batch 1303 of 2603.2 done.
# Batch 1304 of 2603.2 done.
# Batch 1305 of 2603.2 done.
# Batch 1306 of 2603.2 done.
# Batch 1307 of 2603.2 done.
# Batch 1308 of 2603.2 done.
# Batch 1309 of 2603.2 done.
# Batch 1310 of 2603.2 done.
# Batch 1311 of 2603.2 done.
# Batch 1312 of 2603.2 done.
# Batch 1313 of 2603.2 done.
# Batch 1314 of 2603.2 done.
# Batch 1315 of 2603.2 done.
# Batch 1316 of 2603.2 done.
# Batch 1317 of 2603.2 done.
# Batch 1318 of 2603.2 done.
# Batch 1319 of 2603.2 done.
# Batch 1320 of 2603.2 done.
# Batch 1321 of 2603.2 done.
# Batch 1322 of 2603.2 done.
# Batch 1323 of 2603.2 done.
# Batch 1324 of 2603.2 done.
# Batch 1325 of 2603.2 done.
# Batch 1326 of 2603.2 done.
# Batch 1327 of 2603.2 done.
# Batch 1328 of 2603.2 done.
# Batch 1329 of 2603.2 done.
# Batch 1330 of 2603.2 done.
# Batch 1331 of 2603.2 done.
# Batch 1332 of 2603.2 done.
# Batch 1333 of 2603.2 done.
# Batch 1334 of 2603.2 done.
# Batch 1335 of 2603.2 done.
# Batch 1336 of 2603.2 done.
# Batch 1337 of 2603.2 done.
# Batch 1338 of 2603.2 done.
# Batch 1339 of 2603.2 done.
# Batch 1340 of 2603.2 done.
# Batch 1341 of 2603.2 done.
# Batch 1342 of 2603.2 done.
# Batch 1343 of 2603.2 done.
# Batch 1344 of 2603.2 done.
# Batch 1345 of 2603.2 done.
# Batch 1346 of 2603.2 done.
# Batch 1347 of 2603.2 done.
# Batch 1348 of 2603.2 done.
# Batch 1349 of 2603.2 done.
# Batch 1350 of 2603.2 done.
# Batch 1351 of 2603.2 done.
# Batch 1352 of 2603.2 done.
# Batch 1353 of 2603.2 done.
# Batch 1354 of 2603.2 done.
# Batch 1355 of 2603.2 done.
# Batch 1356 of 2603.2 done.
# Batch 1357 of 2603.2 done.
# Batch 1358 of 2603.2 done.
# Batch 1359 of 2603.2 done.
# Batch 1360 of 2603.2 done.
# Batch 1361 of 2603.2 done.
# Batch 1362 of 2603.2 done.
# Batch 1363 of 2603.2 done.
# Batch 1364 of 2603.2 done.
# Batch 1365 of 2603.2 done.
# Batch 1366 of 2603.2 done.
# Batch 1367 of 2603.2 done.
# Batch 1368 of 2603.2 done.
# Batch 1369 of 2603.2 done.
# Batch 1370 of 2603.2 done.
# Batch 1371 of 2603.2 done.
# Batch 1372 of 2603.2 done.
# Batch 1373 of 2603.2 done.
# Batch 1374 of 2603.2 done.
# Batch 1375 of 2603.2 done.
# Batch 1376 of 2603.2 done.
# Batch 1377 of 2603.2 done.
# Batch 1378 of 2603.2 done.
# Batch 1379 of 2603.2 done.
# Batch 1380 of 2603.2 done.
# Batch 1381 of 2603.2 done.
# Batch 1382 of 2603.2 done.
# Batch 1383 of 2603.2 done.
# Batch 1384 of 2603.2 done.
# Batch 1385 of 2603.2 done.
# Batch 1386 of 2603.2 done.
# Batch 1387 of 2603.2 done.
# Batch 1388 of 2603.2 done.
# Batch 1389 of 2603.2 done.
# Batch 1390 of 2603.2 done.
# Batch 1391 of 2603.2 done.
# Batch 1392 of 2603.2 done.
# Batch 1393 of 2603.2 done.
# Batch 1394 of 2603.2 done.
# Batch 1395 of 2603.2 done.
# Batch 1396 of 2603.2 done.
# Batch 1397 of 2603.2 done.
# Batch 1398 of 2603.2 done.
# Batch 1399 of 2603.2 done.
# Batch 1400 of 2603.2 done.
# Batch 1401 of 2603.2 done.
# Batch 1402 of 2603.2 done.
# Batch 1403 of 2603.2 done.
# Batch 1404 of 2603.2 done.
# Batch 1405 of 2603.2 done.
# Batch 1406 of 2603.2 done.
# Batch 1407 of 2603.2 done.
# Batch 1408 of 2603.2 done.
# Batch 1409 of 2603.2 done.
# Batch 1410 of 2603.2 done.
# Batch 1411 of 2603.2 done.
# Batch 1412 of 2603.2 done.
# Batch 1413 of 2603.2 done.
# Batch 1414 of 2603.2 done.
# Batch 1415 of 2603.2 done.
# Batch 1416 of 2603.2 done.
# Batch 1417 of 2603.2 done.
# Batch 1418 of 2603.2 done.
# Batch 1419 of 2603.2 done.
# Batch 1420 of 2603.2 done.
# Batch 1421 of 2603.2 done.
# Batch 1422 of 2603.2 done.
# Batch 1423 of 2603.2 done.
# Batch 1424 of 2603.2 done.
# Batch 1425 of 2603.2 done.
# Batch 1426 of 2603.2 done.
# Batch 1427 of 2603.2 done.
# Batch 1428 of 2603.2 done.
# Batch 1429 of 2603.2 done.
# Batch 1430 of 2603.2 done.
# Batch 1431 of 2603.2 done.
# Batch 1432 of 2603.2 done.
# Batch 1433 of 2603.2 done.
# Batch 1434 of 2603.2 done.
# Batch 1435 of 2603.2 done.
# Batch 1436 of 2603.2 done.
# Batch 1437 of 2603.2 done.
# Batch 1438 of 2603.2 done.
# Batch 1439 of 2603.2 done.
# Batch 1440 of 2603.2 done.
# Batch 1441 of 2603.2 done.
# Batch 1442 of 2603.2 done.
# Batch 1443 of 2603.2 done.
# Batch 1444 of 2603.2 done.
# Batch 1445 of 2603.2 done.
# Batch 1446 of 2603.2 done.
# Batch 1447 of 2603.2 done.
# Batch 1448 of 2603.2 done.
# Batch 1449 of 2603.2 done.
# Batch 1450 of 2603.2 done.
# Batch 1451 of 2603.2 done.
# Batch 1452 of 2603.2 done.
# Batch 1453 of 2603.2 done.
# Batch 1454 of 2603.2 done.
# Batch 1455 of 2603.2 done.
# Batch 1456 of 2603.2 done.
# Batch 1457 of 2603.2 done.
# Batch 1458 of 2603.2 done.
# Batch 1459 of 2603.2 done.
# Batch 1460 of 2603.2 done.
# Batch 1461 of 2603.2 done.
# Batch 1462 of 2603.2 done.
# Batch 1463 of 2603.2 done.
# Batch 1464 of 2603.2 done.
# Batch 1465 of 2603.2 done.
# Batch 1466 of 2603.2 done.
# Batch 1467 of 2603.2 done.
# Batch 1468 of 2603.2 done.
# Batch 1469 of 2603.2 done.
# Batch 1470 of 2603.2 done.
# Batch 1471 of 2603.2 done.
# Batch 1472 of 2603.2 done.
# Batch 1473 of 2603.2 done.
# Batch 1474 of 2603.2 done.
# Batch 1475 of 2603.2 done.
# Batch 1476 of 2603.2 done.
# Batch 1477 of 2603.2 done.
# Batch 1478 of 2603.2 done.
# Batch 1479 of 2603.2 done.
# Batch 1480 of 2603.2 done.
# Batch 1481 of 2603.2 done.
# Batch 1482 of 2603.2 done.
# Batch 1483 of 2603.2 done.
# Batch 1484 of 2603.2 done.
# Batch 1485 of 2603.2 done.
# Batch 1486 of 2603.2 done.
# Batch 1487 of 2603.2 done.
# Batch 1488 of 2603.2 done.
# Batch 1489 of 2603.2 done.
# Batch 1490 of 2603.2 done.
# Batch 1491 of 2603.2 done.
# Batch 1492 of 2603.2 done.
# Batch 1493 of 2603.2 done.
# Batch 1494 of 2603.2 done.
# Batch 1495 of 2603.2 done.
# Batch 1496 of 2603.2 done.
# Batch 1497 of 2603.2 done.
# Batch 1498 of 2603.2 done.
# Batch 1499 of 2603.2 done.
# Batch 1500 of 2603.2 done.
# Batch 1501 of 2603.2 done.
# Batch 1502 of 2603.2 done.
# Batch 1503 of 2603.2 done.
# Batch 1504 of 2603.2 done.
# Batch 1505 of 2603.2 done.
# Batch 1506 of 2603.2 done.
# Batch 1507 of 2603.2 done.
# Batch 1508 of 2603.2 done.
# Batch 1509 of 2603.2 done.
# Batch 1510 of 2603.2 done.
# Batch 1511 of 2603.2 done.
# Batch 1512 of 2603.2 done.
# Batch 1513 of 2603.2 done.
# Batch 1514 of 2603.2 done.
# Batch 1515 of 2603.2 done.
# Batch 1516 of 2603.2 done.
# Batch 1517 of 2603.2 done.
# Batch 1518 of 2603.2 done.
# Batch 1519 of 2603.2 done.
# Batch 1520 of 2603.2 done.
# Batch 1521 of 2603.2 done.
# Batch 1522 of 2603.2 done.
# Batch 1523 of 2603.2 done.
# Batch 1524 of 2603.2 done.
# Batch 1525 of 2603.2 done.
# Batch 1526 of 2603.2 done.
# Batch 1527 of 2603.2 done.
# Batch 1528 of 2603.2 done.
# Batch 1529 of 2603.2 done.
# Batch 1530 of 2603.2 done.
# Batch 1531 of 2603.2 done.
# Batch 1532 of 2603.2 done.
# Batch 1533 of 2603.2 done.
# Batch 1534 of 2603.2 done.
# Batch 1535 of 2603.2 done.
# Batch 1536 of 2603.2 done.
# Batch 1537 of 2603.2 done.
# Batch 1538 of 2603.2 done.
# Batch 1539 of 2603.2 done.
# Batch 1540 of 2603.2 done.
# Batch 1541 of 2603.2 done.
# Batch 1542 of 2603.2 done.
# Batch 1543 of 2603.2 done.
# Batch 1544 of 2603.2 done.
# Batch 1545 of 2603.2 done.
# Batch 1546 of 2603.2 done.
# Batch 1547 of 2603.2 done.
# Batch 1548 of 2603.2 done.
# Batch 1549 of 2603.2 done.
# Batch 1550 of 2603.2 done.
# Batch 1551 of 2603.2 done.
# Batch 1552 of 2603.2 done.
# Batch 1553 of 2603.2 done.
# Batch 1554 of 2603.2 done.
# Batch 1555 of 2603.2 done.
# Batch 1556 of 2603.2 done.
# Batch 1557 of 2603.2 done.
# Batch 1558 of 2603.2 done.
# Batch 1559 of 2603.2 done.
# Batch 1560 of 2603.2 done.
# Batch 1561 of 2603.2 done.
# Batch 1562 of 2603.2 done.
# Batch 1563 of 2603.2 done.
# Batch 1564 of 2603.2 done.
# Batch 1565 of 2603.2 done.
# Batch 1566 of 2603.2 done.
# Batch 1567 of 2603.2 done.
# Batch 1568 of 2603.2 done.
# Batch 1569 of 2603.2 done.
# Batch 1570 of 2603.2 done.
# Batch 1571 of 2603.2 done.
# Batch 1572 of 2603.2 done.
# Batch 1573 of 2603.2 done.
# Batch 1574 of 2603.2 done.
# Batch 1575 of 2603.2 done.
# Batch 1576 of 2603.2 done.
# Batch 1577 of 2603.2 done.
# Batch 1578 of 2603.2 done.
# Batch 1579 of 2603.2 done.
# Batch 1580 of 2603.2 done.
# Batch 1581 of 2603.2 done.
# Batch 1582 of 2603.2 done.
# Batch 1583 of 2603.2 done.
# Batch 1584 of 2603.2 done.
# Batch 1585 of 2603.2 done.
# Batch 1586 of 2603.2 done.
# Batch 1587 of 2603.2 done.
# Batch 1588 of 2603.2 done.
# Batch 1589 of 2603.2 done.
# Batch 1590 of 2603.2 done.
# Batch 1591 of 2603.2 done.
# Batch 1592 of 2603.2 done.
# Batch 1593 of 2603.2 done.
# Batch 1594 of 2603.2 done.
# Batch 1595 of 2603.2 done.
# Batch 1596 of 2603.2 done.
# Batch 1597 of 2603.2 done.
# Batch 1598 of 2603.2 done.
# Batch 1599 of 2603.2 done.
# Batch 1600 of 2603.2 done.
# Batch 1601 of 2603.2 done.
# Batch 1602 of 2603.2 done.
# Batch 1603 of 2603.2 done.
# Batch 1604 of 2603.2 done.
# Batch 1605 of 2603.2 done.
# Batch 1606 of 2603.2 done.
# Batch 1607 of 2603.2 done.
# Batch 1608 of 2603.2 done.
# Batch 1609 of 2603.2 done.
# Batch 1610 of 2603.2 done.
# Batch 1611 of 2603.2 done.
# Batch 1612 of 2603.2 done.
# Batch 1613 of 2603.2 done.
# Batch 1614 of 2603.2 done.
# Batch 1615 of 2603.2 done.
# Batch 1616 of 2603.2 done.
# Batch 1617 of 2603.2 done.
# Batch 1618 of 2603.2 done.
# Batch 1619 of 2603.2 done.
# Batch 1620 of 2603.2 done.
# Batch 1621 of 2603.2 done.
# Batch 1622 of 2603.2 done.
# Batch 1623 of 2603.2 done.
# Batch 1624 of 2603.2 done.
# Batch 1625 of 2603.2 done.
# Batch 1626 of 2603.2 done.
# Batch 1627 of 2603.2 done.
# Batch 1628 of 2603.2 done.
# Batch 1629 of 2603.2 done.
# Batch 1630 of 2603.2 done.
# Batch 1631 of 2603.2 done.
# Batch 1632 of 2603.2 done.
# Batch 1633 of 2603.2 done.
# Batch 1634 of 2603.2 done.
# Batch 1635 of 2603.2 done.
# Batch 1636 of 2603.2 done.
# Batch 1637 of 2603.2 done.
# Batch 1638 of 2603.2 done.
# Batch 1639 of 2603.2 done.
# Batch 1640 of 2603.2 done.
# Batch 1641 of 2603.2 done.
# Batch 1642 of 2603.2 done.
# Batch 1643 of 2603.2 done.
# Batch 1644 of 2603.2 done.
# Batch 1645 of 2603.2 done.
# Batch 1646 of 2603.2 done.
# Batch 1647 of 2603.2 done.
# Batch 1648 of 2603.2 done.
# Batch 1649 of 2603.2 done.
# Batch 1650 of 2603.2 done.
# Batch 1651 of 2603.2 done.
# Batch 1652 of 2603.2 done.
# Batch 1653 of 2603.2 done.
# Batch 1654 of 2603.2 done.
# Batch 1655 of 2603.2 done.
# Batch 1656 of 2603.2 done.
# Batch 1657 of 2603.2 done.
# Batch 1658 of 2603.2 done.
# Batch 1659 of 2603.2 done.
# Batch 1660 of 2603.2 done.
# Batch 1661 of 2603.2 done.
# Batch 1662 of 2603.2 done.
# Batch 1663 of 2603.2 done.
# Batch 1664 of 2603.2 done.
# Batch 1665 of 2603.2 done.
# Batch 1666 of 2603.2 done.
# Batch 1667 of 2603.2 done.
# Batch 1668 of 2603.2 done.
# Batch 1669 of 2603.2 done.
# Batch 1670 of 2603.2 done.
# Batch 1671 of 2603.2 done.
# Batch 1672 of 2603.2 done.
# Batch 1673 of 2603.2 done.
# Batch 1674 of 2603.2 done.
# Batch 1675 of 2603.2 done.
# Batch 1676 of 2603.2 done.
# Batch 1677 of 2603.2 done.
# Batch 1678 of 2603.2 done.
# Batch 1679 of 2603.2 done.
# Batch 1680 of 2603.2 done.
# Batch 1681 of 2603.2 done.
# Batch 1682 of 2603.2 done.
# Batch 1683 of 2603.2 done.
# Batch 1684 of 2603.2 done.
# Batch 1685 of 2603.2 done.
# Batch 1686 of 2603.2 done.
# Batch 1687 of 2603.2 done.
# Batch 1688 of 2603.2 done.
# Batch 1689 of 2603.2 done.
# Batch 1690 of 2603.2 done.
# Batch 1691 of 2603.2 done.
# Batch 1692 of 2603.2 done.
# Batch 1693 of 2603.2 done.
# Batch 1694 of 2603.2 done.
# Batch 1695 of 2603.2 done.
# Batch 1696 of 2603.2 done.
# Batch 1697 of 2603.2 done.
# Batch 1698 of 2603.2 done.
# Batch 1699 of 2603.2 done.
# Batch 1700 of 2603.2 done.
# Batch 1701 of 2603.2 done.
# Batch 1702 of 2603.2 done.
# Batch 1703 of 2603.2 done.
# Batch 1704 of 2603.2 done.
# Batch 1705 of 2603.2 done.
# Batch 1706 of 2603.2 done.
# Batch 1707 of 2603.2 done.
# Batch 1708 of 2603.2 done.
# Batch 1709 of 2603.2 done.
# Batch 1710 of 2603.2 done.
# Batch 1711 of 2603.2 done.
# Batch 1712 of 2603.2 done.
# Batch 1713 of 2603.2 done.
# Batch 1714 of 2603.2 done.
# Batch 1715 of 2603.2 done.
# Batch 1716 of 2603.2 done.
# Batch 1717 of 2603.2 done.
# Batch 1718 of 2603.2 done.
# Batch 1719 of 2603.2 done.
# Batch 1720 of 2603.2 done.
# Batch 1721 of 2603.2 done.
# Batch 1722 of 2603.2 done.
# Batch 1723 of 2603.2 done.
# Batch 1724 of 2603.2 done.
# Batch 1725 of 2603.2 done.
# Batch 1726 of 2603.2 done.
# Batch 1727 of 2603.2 done.
# Batch 1728 of 2603.2 done.
# Batch 1729 of 2603.2 done.
# Batch 1730 of 2603.2 done.
# Batch 1731 of 2603.2 done.
# Batch 1732 of 2603.2 done.
# Batch 1733 of 2603.2 done.
# Batch 1734 of 2603.2 done.
# Batch 1735 of 2603.2 done.
# Batch 1736 of 2603.2 done.
# Batch 1737 of 2603.2 done.
# Batch 1738 of 2603.2 done.
# Batch 1739 of 2603.2 done.
# Batch 1740 of 2603.2 done.
# Batch 1741 of 2603.2 done.
# Batch 1742 of 2603.2 done.
# Batch 1743 of 2603.2 done.
# Batch 1744 of 2603.2 done.
# Batch 1745 of 2603.2 done.
# Batch 1746 of 2603.2 done.
# Batch 1747 of 2603.2 done.
# Batch 1748 of 2603.2 done.
# Batch 1749 of 2603.2 done.
# Batch 1750 of 2603.2 done.
# Batch 1751 of 2603.2 done.
# Batch 1752 of 2603.2 done.
# Batch 1753 of 2603.2 done.
# Batch 1754 of 2603.2 done.
# Batch 1755 of 2603.2 done.
# Batch 1756 of 2603.2 done.
# Batch 1757 of 2603.2 done.
# Batch 1758 of 2603.2 done.
# Batch 1759 of 2603.2 done.
# Batch 1760 of 2603.2 done.
# Batch 1761 of 2603.2 done.
# Batch 1762 of 2603.2 done.
# Batch 1763 of 2603.2 done.
# Batch 1764 of 2603.2 done.
# Batch 1765 of 2603.2 done.
# Batch 1766 of 2603.2 done.
# Batch 1767 of 2603.2 done.
# Batch 1768 of 2603.2 done.
# Batch 1769 of 2603.2 done.
# Batch 1770 of 2603.2 done.
# Batch 1771 of 2603.2 done.
# Batch 1772 of 2603.2 done.
# Batch 1773 of 2603.2 done.
# Batch 1774 of 2603.2 done.
# Batch 1775 of 2603.2 done.
# Batch 1776 of 2603.2 done.
# Batch 1777 of 2603.2 done.
# Batch 1778 of 2603.2 done.
# Batch 1779 of 2603.2 done.
# Batch 1780 of 2603.2 done.
# Batch 1781 of 2603.2 done.
# Batch 1782 of 2603.2 done.
# Batch 1783 of 2603.2 done.
# Batch 1784 of 2603.2 done.
# Batch 1785 of 2603.2 done.
# Batch 1786 of 2603.2 done.
# Batch 1787 of 2603.2 done.
# Batch 1788 of 2603.2 done.
# Batch 1789 of 2603.2 done.
# Batch 1790 of 2603.2 done.
# Batch 1791 of 2603.2 done.
# Batch 1792 of 2603.2 done.
# Batch 1793 of 2603.2 done.
# Batch 1794 of 2603.2 done.
# Batch 1795 of 2603.2 done.
# Batch 1796 of 2603.2 done.
# Batch 1797 of 2603.2 done.
# Batch 1798 of 2603.2 done.
# Batch 1799 of 2603.2 done.
# Batch 1800 of 2603.2 done.
# Batch 1801 of 2603.2 done.
# Batch 1802 of 2603.2 done.
# Batch 1803 of 2603.2 done.
# Batch 1804 of 2603.2 done.
# Batch 1805 of 2603.2 done.
# Batch 1806 of 2603.2 done.
# Batch 1807 of 2603.2 done.
# Batch 1808 of 2603.2 done.
# Batch 1809 of 2603.2 done.
# Batch 1810 of 2603.2 done.
# Batch 1811 of 2603.2 done.
# Batch 1812 of 2603.2 done.
# Batch 1813 of 2603.2 done.
# Batch 1814 of 2603.2 done.
# Batch 1815 of 2603.2 done.
# Batch 1816 of 2603.2 done.
# Batch 1817 of 2603.2 done.
# ...
# Batch 2012 of 2603.2 done.
# Batch 2013 of 2603.2 done.
# Batch 2014 of 2603.2 done.
# Batch 2015 of 2603.2 done.
# Batch 2016 of 2603.2 done.
# Batch 2017 of 2603.2 done.
# Batch 2018 of 2603.2 done.
# Batch 2019 of 2603.2 done.
# Batch 2020 of 2603.2 done.
# Batch 2021 of 2603.2 done.
# Batch 2022 of 2603.2 done.
# Batch 2023 of 2603.2 done.
# Batch 2024 of 2603.2 done.
# Batch 2025 of 2603.2 done.
# Batch 2026 of 2603.2 done.
# Batch 2027 of 2603.2 done.
# Batch 2028 of 2603.2 done.
# Batch 2029 of 2603.2 done.
# Batch 2030 of 2603.2 done.
# Batch 2031 of 2603.2 done.
# Batch 2032 of 2603.2 done.
# Batch 2033 of 2603.2 done.
# Batch 2034 of 2603.2 done.
# Batch 2035 of 2603.2 done.
# Batch 2036 of 2603.2 done.
# Batch 2037 of 2603.2 done.
# Batch 2038 of 2603.2 done.
# Batch 2039 of 2603.2 done.
# Batch 2040 of 2603.2 done.
# Batch 2041 of 2603.2 done.
# Batch 2042 of 2603.2 done.
# Batch 2043 of 2603.2 done.
# Batch 2044 of 2603.2 done.
# Batch 2045 of 2603.2 done.
# Batch 2046 of 2603.2 done.
# Batch 2047 of 2603.2 done.
# Batch 2048 of 2603.2 done.
# Batch 2049 of 2603.2 done.
# Batch 2050 of 2603.2 done.
# Batch 2051 of 2603.2 done.
# Batch 2052 of 2603.2 done.
# Batch 2053 of 2603.2 done.
# Batch 2054 of 2603.2 done.
# Batch 2055 of 2603.2 done.
# Batch 2056 of 2603.2 done.
# Batch 2057 of 2603.2 done.
# Batch 2058 of 2603.2 done.
# Batch 2059 of 2603.2 done.
# Batch 2060 of 2603.2 done.
# Batch 2061 of 2603.2 done.
# Batch 2062 of 2603.2 done.
# Batch 2063 of 2603.2 done.
# Batch 2064 of 2603.2 done.
# Batch 2065 of 2603.2 done.
# Batch 2066 of 2603.2 done.
# Batch 2067 of 2603.2 done.
# Batch 2068 of 2603.2 done.
# Batch 2069 of 2603.2 done.
# Batch 2070 of 2603.2 done.
# Batch 2071 of 2603.2 done.
# Batch 2072 of 2603.2 done.
# Batch 2073 of 2603.2 done.
# Batch 2074 of 2603.2 done.
# Batch 2075 of 2603.2 done.
# Batch 2076 of 2603.2 done.
# Batch 2077 of 2603.2 done.
# Batch 2078 of 2603.2 done.
# Batch 2079 of 2603.2 done.
# Batch 2080 of 2603.2 done.
# Batch 2081 of 2603.2 done.
# Batch 2082 of 2603.2 done.
# Batch 2083 of 2603.2 done.
# Batch 2084 of 2603.2 done.
# Batch 2085 of 2603.2 done.
# Batch 2086 of 2603.2 done.
# Batch 2087 of 2603.2 done.
# Batch 2088 of 2603.2 done.
# Batch 2089 of 2603.2 done.
# Batch 2090 of 2603.2 done.
# Batch 2091 of 2603.2 done.
# Batch 2092 of 2603.2 done.
# Batch 2093 of 2603.2 done.
# Batch 2094 of 2603.2 done.
# Batch 2095 of 2603.2 done.
# Batch 2096 of 2603.2 done.
# Batch 2097 of 2603.2 done.
# Batch 2098 of 2603.2 done.
# Batch 2099 of 2603.2 done.
# Batch 2100 of 2603.2 done.
# Batch 2101 of 2603.2 done.
# Batch 2102 of 2603.2 done.
# Batch 2103 of 2603.2 done.
# Batch 2104 of 2603.2 done.
# Batch 2105 of 2603.2 done.
# Batch 2106 of 2603.2 done.
# Batch 2107 of 2603.2 done.
# Batch 2108 of 2603.2 done.
# Batch 2109 of 2603.2 done.
# Batch 2110 of 2603.2 done.
# Batch 2111 of 2603.2 done.
# Batch 2112 of 2603.2 done.
# Batch 2113 of 2603.2 done.
# Batch 2114 of 2603.2 done.
# Batch 2115 of 2603.2 done.
# Batch 2116 of 2603.2 done.
# Batch 2117 of 2603.2 done.
# Batch 2118 of 2603.2 done.
# Batch 2119 of 2603.2 done.
# Batch 2120 of 2603.2 done.
# Batch 2121 of 2603.2 done.
# Batch 2122 of 2603.2 done.
# Batch 2123 of 2603.2 done.
# Batch 2124 of 2603.2 done.
# Batch 2125 of 2603.2 done.
# Batch 2126 of 2603.2 done.
# Batch 2127 of 2603.2 done.
# Batch 2128 of 2603.2 done.
# Batch 2129 of 2603.2 done.
# Batch 2130 of 2603.2 done.
# Batch 2131 of 2603.2 done.
# Batch 2132 of 2603.2 done.
# Batch 2133 of 2603.2 done.
# Batch 2134 of 2603.2 done.
# Batch 2135 of 2603.2 done.
# Batch 2136 of 2603.2 done.
# Batch 2137 of 2603.2 done.
# Batch 2138 of 2603.2 done.
# Batch 2139 of 2603.2 done.
# Batch 2140 of 2603.2 done.
# Batch 2141 of 2603.2 done.
# Batch 2142 of 2603.2 done.
# Batch 2143 of 2603.2 done.
# Batch 2144 of 2603.2 done.
# Batch 2145 of 2603.2 done.
# Batch 2146 of 2603.2 done.
# Batch 2147 of 2603.2 done.
# Batch 2148 of 2603.2 done.
# Batch 2149 of 2603.2 done.
# Batch 2150 of 2603.2 done.
# Batch 2151 of 2603.2 done.
# Batch 2152 of 2603.2 done.
# Batch 2153 of 2603.2 done.
# Batch 2154 of 2603.2 done.
# Batch 2155 of 2603.2 done.
# Batch 2156 of 2603.2 done.
# Batch 2157 of 2603.2 done.
# Batch 2158 of 2603.2 done.
# Batch 2159 of 2603.2 done.
# Batch 2160 of 2603.2 done.
# Batch 2161 of 2603.2 done.
# Batch 2162 of 2603.2 done.
# Batch 2163 of 2603.2 done.
# Batch 2164 of 2603.2 done.
# Batch 2165 of 2603.2 done.
# Batch 2166 of 2603.2 done.
# Batch 2167 of 2603.2 done.
# Batch 2168 of 2603.2 done.
# Batch 2169 of 2603.2 done.
# Batch 2170 of 2603.2 done.
# Batch 2171 of 2603.2 done.
# Batch 2172 of 2603.2 done.
# Batch 2173 of 2603.2 done.
# Batch 2174 of 2603.2 done.
# Batch 2175 of 2603.2 done.
# Batch 2176 of 2603.2 done.
# Batch 2177 of 2603.2 done.
# Batch 2178 of 2603.2 done.
# Batch 2179 of 2603.2 done.
# Batch 2180 of 2603.2 done.
# Batch 2181 of 2603.2 done.
# Batch 2182 of 2603.2 done.
# Batch 2183 of 2603.2 done.
# Batch 2184 of 2603.2 done.
# Batch 2185 of 2603.2 done.
# Batch 2186 of 2603.2 done.
# Batch 2187 of 2603.2 done.
# Batch 2188 of 2603.2 done.
# Batch 2189 of 2603.2 done.
# Batch 2190 of 2603.2 done.
# Batch 2191 of 2603.2 done.
# Batch 2192 of 2603.2 done.
# Batch 2193 of 2603.2 done.
# Batch 2194 of 2603.2 done.
# Batch 2195 of 2603.2 done.
# Batch 2196 of 2603.2 done.
# Batch 2197 of 2603.2 done.
# Batch 2198 of 2603.2 done.
# Batch 2199 of 2603.2 done.
# Batch 2200 of 2603.2 done.
# Batch 2201 of 2603.2 done.
# Batch 2202 of 2603.2 done.
# Batch 2203 of 2603.2 done.
# Batch 2204 of 2603.2 done.
# Batch 2205 of 2603.2 done.
# Batch 2206 of 2603.2 done.
# Batch 2207 of 2603.2 done.
# Batch 2208 of 2603.2 done.
# Batch 2209 of 2603.2 done.
# Batch 2210 of 2603.2 done.
# Batch 2211 of 2603.2 done.
# Batch 2212 of 2603.2 done.
# Batch 2213 of 2603.2 done.
# Batch 2214 of 2603.2 done.
# Batch 2215 of 2603.2 done.
# Batch 2216 of 2603.2 done.
# Batch 2217 of 2603.2 done.
# Batch 2218 of 2603.2 done.
# Batch 2219 of 2603.2 done.
# Batch 2220 of 2603.2 done.
# Batch 2221 of 2603.2 done.
# Batch 2222 of 2603.2 done.
# Batch 2223 of 2603.2 done.
# Batch 2224 of 2603.2 done.
# Batch 2225 of 2603.2 done.
# Batch 2226 of 2603.2 done.
# Batch 2227 of 2603.2 done.
# Batch 2228 of 2603.2 done.
# Batch 2229 of 2603.2 done.
# Batch 2230 of 2603.2 done.
# Batch 2231 of 2603.2 done.
# Batch 2232 of 2603.2 done.
# Batch 2233 of 2603.2 done.
# Batch 2234 of 2603.2 done.
# Batch 2235 of 2603.2 done.
# Batch 2236 of 2603.2 done.
# Batch 2237 of 2603.2 done.
# Batch 2238 of 2603.2 done.
# Batch 2239 of 2603.2 done.
# Batch 2240 of 2603.2 done.
# Batch 2241 of 2603.2 done.
# Batch 2242 of 2603.2 done.
# Batch 2243 of 2603.2 done.
# Batch 2244 of 2603.2 done.
# Batch 2245 of 2603.2 done.
# Batch 2246 of 2603.2 done.
# Batch 2247 of 2603.2 done.
# Batch 2248 of 2603.2 done.
# Batch 2249 of 2603.2 done.
# Batch 2250 of 2603.2 done.
# Batch 2251 of 2603.2 done.
# Batch 2252 of 2603.2 done.
# Batch 2253 of 2603.2 done.
# Batch 2254 of 2603.2 done.
# Batch 2255 of 2603.2 done.
# Batch 2256 of 2603.2 done.
# Batch 2257 of 2603.2 done.
# Batch 2258 of 2603.2 done.
# Batch 2259 of 2603.2 done.
# Batch 2260 of 2603.2 done.
# Batch 2261 of 2603.2 done.
# Batch 2262 of 2603.2 done.
# Batch 2263 of 2603.2 done.
# Batch 2264 of 2603.2 done.
# Batch 2265 of 2603.2 done.
# Batch 2266 of 2603.2 done.
# Batch 2267 of 2603.2 done.
# Batch 2268 of 2603.2 done.
# Batch 2269 of 2603.2 done.
# Batch 2270 of 2603.2 done.
# Batch 2271 of 2603.2 done.
# Batch 2272 of 2603.2 done.
# Batch 2273 of 2603.2 done.
# Batch 2274 of 2603.2 done.
# Batch 2275 of 2603.2 done.
# Batch 2276 of 2603.2 done.
# Batch 2277 of 2603.2 done.
# Batch 2278 of 2603.2 done.
# Batch 2279 of 2603.2 done.
# Batch 2280 of 2603.2 done.
# Batch 2281 of 2603.2 done.
# Batch 2282 of 2603.2 done.
# Batch 2283 of 2603.2 done.
# Batch 2284 of 2603.2 done.
# Batch 2285 of 2603.2 done.
# Batch 2286 of 2603.2 done.
# Batch 2287 of 2603.2 done.
# Batch 2288 of 2603.2 done.
# Batch 2289 of 2603.2 done.
# Batch 2290 of 2603.2 done.
# Batch 2291 of 2603.2 done.
# Batch 2292 of 2603.2 done.
# Batch 2293 of 2603.2 done.
# Batch 2294 of 2603.2 done.
# Batch 2295 of 2603.2 done.
# Batch 2296 of 2603.2 done.
# Batch 2297 of 2603.2 done.
# Batch 2298 of 2603.2 done.
# Batch 2299 of 2603.2 done.
# Batch 2300 of 2603.2 done.
# Batch 2301 of 2603.2 done.
# Batch 2302 of 2603.2 done.
# Batch 2303 of 2603.2 done.
# Batch 2304 of 2603.2 done.
# Batch 2305 of 2603.2 done.
# Batch 2306 of 2603.2 done.
# Batch 2307 of 2603.2 done.
# Batch 2308 of 2603.2 done.
# Batch 2309 of 2603.2 done.
# Batch 2310 of 2603.2 done.
# Batch 2311 of 2603.2 done.
# Batch 2312 of 2603.2 done.
# Batch 2313 of 2603.2 done.
# Batch 2314 of 2603.2 done.
# Batch 2315 of 2603.2 done.
# Batch 2316 of 2603.2 done.
# Batch 2317 of 2603.2 done.
# Batch 2318 of 2603.2 done.
# Batch 2319 of 2603.2 done.
# Batch 2320 of 2603.2 done.
# Batch 2321 of 2603.2 done.
# Batch 2322 of 2603.2 done.
# Batch 2323 of 2603.2 done.
# Batch 2324 of 2603.2 done.
# Batch 2325 of 2603.2 done.
# Batch 2326 of 2603.2 done.
# Batch 2327 of 2603.2 done.
# Batch 2328 of 2603.2 done.
# Batch 2329 of 2603.2 done.
# Batch 2330 of 2603.2 done.
# Batch 2331 of 2603.2 done.
# Batch 2332 of 2603.2 done.
# Batch 2333 of 2603.2 done.
# Batch 2334 of 2603.2 done.
# Batch 2335 of 2603.2 done.
# Batch 2336 of 2603.2 done.
# Batch 2337 of 2603.2 done.
# Batch 2338 of 2603.2 done.
# Batch 2339 of 2603.2 done.
# Batch 2340 of 2603.2 done.
# Batch 2341 of 2603.2 done.
# Batch 2342 of 2603.2 done.
# Batch 2343 of 2603.2 done.
# Batch 2344 of 2603.2 done.
# Batch 2345 of 2603.2 done.
# Batch 2346 of 2603.2 done.
# Batch 2347 of 2603.2 done.
# Batch 2348 of 2603.2 done.
# Batch 2349 of 2603.2 done.
# Batch 2350 of 2603.2 done.
# Batch 2351 of 2603.2 done.
# Batch 2352 of 2603.2 done.
# Batch 2353 of 2603.2 done.
# Batch 2354 of 2603.2 done.
# Batch 2355 of 2603.2 done.
# Batch 2356 of 2603.2 done.
# Batch 2357 of 2603.2 done.
# Batch 2358 of 2603.2 done.
# Batch 2359 of 2603.2 done.
# Batch 2360 of 2603.2 done.
# Batch 2361 of 2603.2 done.
# Batch 2362 of 2603.2 done.
# Batch 2363 of 2603.2 done.
# Batch 2364 of 2603.2 done.
# Batch 2365 of 2603.2 done.
# Batch 2366 of 2603.2 done.
# Batch 2367 of 2603.2 done.
# Batch 2368 of 2603.2 done.
# Batch 2369 of 2603.2 done.
# Batch 2370 of 2603.2 done.
# Batch 2371 of 2603.2 done.
# Batch 2372 of 2603.2 done.
# Batch 2373 of 2603.2 done.
# Batch 2374 of 2603.2 done.
# Batch 2375 of 2603.2 done.
# Batch 2376 of 2603.2 done.
# Batch 2377 of 2603.2 done.
# Batch 2378 of 2603.2 done.
# Batch 2379 of 2603.2 done.
# Batch 2380 of 2603.2 done.
# Batch 2381 of 2603.2 done.
# Batch 2382 of 2603.2 done.
# Batch 2383 of 2603.2 done.
# Batch 2384 of 2603.2 done.
# Batch 2385 of 2603.2 done.
# Batch 2386 of 2603.2 done.
# Batch 2387 of 2603.2 done.
# Batch 2388 of 2603.2 done.
# Batch 2389 of 2603.2 done.
# Batch 2390 of 2603.2 done.
# Batch 2391 of 2603.2 done.
# Batch 2392 of 2603.2 done.
# Batch 2393 of 2603.2 done.
# Batch 2394 of 2603.2 done.
# Batch 2395 of 2603.2 done.
# Batch 2396 of 2603.2 done.
# Batch 2397 of 2603.2 done.
# Batch 2398 of 2603.2 done.
# Batch 2399 of 2603.2 done.
# Batch 2400 of 2603.2 done.
# Batch 2401 of 2603.2 done.
# Batch 2402 of 2603.2 done.
# Batch 2403 of 2603.2 done.
# Batch 2404 of 2603.2 done.
# Batch 2405 of 2603.2 done.
# Batch 2406 of 2603.2 done.
# Batch 2407 of 2603.2 done.
# Batch 2408 of 2603.2 done.
# Batch 2409 of 2603.2 done.
# Batch 2410 of 2603.2 done.
# Batch 2411 of 2603.2 done.
# Batch 2412 of 2603.2 done.
# Batch 2413 of 2603.2 done.
# Batch 2414 of 2603.2 done.
# Batch 2415 of 2603.2 done.
# Batch 2416 of 2603.2 done.
# Batch 2417 of 2603.2 done.
# Batch 2418 of 2603.2 done.
# Batch 2419 of 2603.2 done.
# Batch 2420 of 2603.2 done.
# Batch 2421 of 2603.2 done.
# Batch 2422 of 2603.2 done.
# Batch 2423 of 2603.2 done.
# Batch 2424 of 2603.2 done.
# Batch 2425 of 2603.2 done.
# Batch 2426 of 2603.2 done.
# Batch 2427 of 2603.2 done.
# Batch 2428 of 2603.2 done.
# Batch 2429 of 2603.2 done.
# Batch 2430 of 2603.2 done.
# Batch 2431 of 2603.2 done.
# Batch 2432 of 2603.2 done.
# Batch 2433 of 2603.2 done.
# Batch 2434 of 2603.2 done.
# Batch 2435 of 2603.2 done.
# Batch 2436 of 2603.2 done.
# Batch 2437 of 2603.2 done.
# Batch 2438 of 2603.2 done.
# Batch 2439 of 2603.2 done.
# Batch 2440 of 2603.2 done.
# Batch 2441 of 2603.2 done.
# Batch 2442 of 2603.2 done.
# Batch 2443 of 2603.2 done.
# Batch 2444 of 2603.2 done.
# Batch 2445 of 2603.2 done.
# Batch 2446 of 2603.2 done.
# Batch 2447 of 2603.2 done.
# Batch 2448 of 2603.2 done.
# Batch 2449 of 2603.2 done.
# Batch 2450 of 2603.2 done.
# Batch 2451 of 2603.2 done.
# Batch 2452 of 2603.2 done.
# Batch 2453 of 2603.2 done.
# Batch 2454 of 2603.2 done.
# Batch 2455 of 2603.2 done.
# Batch 2456 of 2603.2 done.
# Batch 2457 of 2603.2 done.
# Batch 2458 of 2603.2 done.
# Batch 2459 of 2603.2 done.
# Batch 2460 of 2603.2 done.
# Batch 2461 of 2603.2 done.
# Batch 2462 of 2603.2 done.
# Batch 2463 of 2603.2 done.
# Batch 2464 of 2603.2 done.
# Batch 2465 of 2603.2 done.
# Batch 2466 of 2603.2 done.
# Batch 2467 of 2603.2 done.
# Batch 2468 of 2603.2 done.
# Batch 2469 of 2603.2 done.
# Batch 2470 of 2603.2 done.
# Batch 2471 of 2603.2 done.
# Batch 2472 of 2603.2 done.
# Batch 2473 of 2603.2 done.
# Batch 2474 of 2603.2 done.
# Batch 2475 of 2603.2 done.
# Batch 2476 of 2603.2 done.
# Batch 2477 of 2603.2 done.
# Batch 2478 of 2603.2 done.
# Batch 2479 of 2603.2 done.
# Batch 2480 of 2603.2 done.
# Batch 2481 of 2603.2 done.
# Batch 2482 of 2603.2 done.
# Batch 2483 of 2603.2 done.
# Batch 2484 of 2603.2 done.
# Batch 2485 of 2603.2 done.
# Batch 2486 of 2603.2 done.
# Batch 2487 of 2603.2 done.
# Batch 2488 of 2603.2 done.
# Batch 2489 of 2603.2 done.
# Batch 2490 of 2603.2 done.
# Batch 2491 of 2603.2 done.
# Batch 2492 of 2603.2 done.
# Batch 2493 of 2603.2 done.
# Batch 2494 of 2603.2 done.
# Batch 2495 of 2603.2 done.
# Batch 2496 of 2603.2 done.
# Batch 2497 of 2603.2 done.
# Batch 2498 of 2603.2 done.
# Batch 2499 of 2603.2 done.
# Batch 2500 of 2603.2 done.
# Batch 2501 of 2603.2 done.
# Batch 2502 of 2603.2 done.
# Batch 2503 of 2603.2 done.
# Batch 2504 of 2603.2 done.
# Batch 2505 of 2603.2 done.
# Batch 2506 of 2603.2 done.
# Batch 2507 of 2603.2 done.
# Batch 2508 of 2603.2 done.
# Batch 2509 of 2603.2 done.
# Batch 2510 of 2603.2 done.
# Batch 2511 of 2603.2 done.
# Batch 2512 of 2603.2 done.
# Batch 2513 of 2603.2 done.
# Batch 2514 of 2603.2 done.
# Batch 2515 of 2603.2 done.
# Batch 2516 of 2603.2 done.
# Batch 2517 of 2603.2 done.
# Batch 2518 of 2603.2 done.
# Batch 2519 of 2603.2 done.
# Batch 2520 of 2603.2 done.
# Batch 2521 of 2603.2 done.
# Batch 2522 of 2603.2 done.
# Batch 2523 of 2603.2 done.
# Batch 2524 of 2603.2 done.
# Batch 2525 of 2603.2 done.
# Batch 2526 of 2603.2 done.
# Batch 2527 of 2603.2 done.
# Batch 2528 of 2603.2 done.
# Batch 2529 of 2603.2 done.
# Batch 2530 of 2603.2 done.
# Batch 2531 of 2603.2 done.
# Batch 2532 of 2603.2 done.
# Batch 2533 of 2603.2 done.
# Batch 2534 of 2603.2 done.
# Batch 2535 of 2603.2 done.
# Batch 2536 of 2603.2 done.
# Batch 2537 of 2603.2 done.
# Batch 2538 of 2603.2 done.
# Batch 2539 of 2603.2 done.
# Batch 2540 of 2603.2 done.
# Batch 2541 of 2603.2 done.
# Batch 2542 of 2603.2 done.
# Batch 2543 of 2603.2 done.
# Batch 2544 of 2603.2 done.
# Batch 2545 of 2603.2 done.
# Batch 2546 of 2603.2 done.
# Batch 2547 of 2603.2 done.
# Batch 2548 of 2603.2 done.
# Batch 2549 of 2603.2 done.
# Batch 2550 of 2603.2 done.
# Batch 2551 of 2603.2 done.
# Batch 2552 of 2603.2 done.
# Batch 2553 of 2603.2 done.
# Batch 2554 of 2603.2 done.
# Batch 2555 of 2603.2 done.
# Batch 2556 of 2603.2 done.
# Batch 2557 of 2603.2 done.
# Batch 2558 of 2603.2 done.
# Batch 2559 of 2603.2 done.
# Batch 2560 of 2603.2 done.
# Batch 2561 of 2603.2 done.
# Batch 2562 of 2603.2 done.
# Batch 2563 of 2603.2 done.
# Batch 2564 of 2603.2 done.
# Batch 2565 of 2603.2 done.
# Batch 2566 of 2603.2 done.
# Batch 2567 of 2603.2 done.
# Batch 2568 of 2603.2 done.
# Batch 2569 of 2603.2 done.
# Batch 2570 of 2603.2 done.
# Batch 2571 of 2603.2 done.
# Batch 2572 of 2603.2 done.
# Batch 2573 of 2603.2 done.
# Batch 2574 of 2603.2 done.
# Batch 2575 of 2603.2 done.
# Batch 2576 of 2603.2 done.
# Batch 2577 of 2603.2 done.
# Batch 2578 of 2603.2 done.
# Batch 2579 of 2603.2 done.
# Batch 2580 of 2603.2 done.
# Batch 2581 of 2603.2 done.
# Batch 2582 of 2603.2 done.
# Batch 2583 of 2603.2 done.
# Batch 2584 of 2603.2 done.
# Batch 2585 of 2603.2 done.
# Batch 2586 of 2603.2 done.
# Batch 2587 of 2603.2 done.
# Batch 2588 of 2603.2 done.
# Batch 2589 of 2603.2 done.
# Batch 2590 of 2603.2 done.
# Batch 2591 of 2603.2 done.
# Batch 2592 of 2603.2 done.
# Batch 2593 of 2603.2 done.
# Batch 2594 of 2603.2 done.
# Batch 2595 of 2603.2 done.
# Batch 2596 of 2603.2 done.
# Batch 2597 of 2603.2 done.
# Batch 2598 of 2603.2 done.
# Batch 2599 of 2603.2 done.
# Batch 2600 of 2603.2 done.
# Batch 2601 of 2603.2 done.
# Batch 2602 of 2603.2 done.
# Batch 2603 of 2603.2 done.

# %%
print(loss_avg, acc_avg)
# Out:
# 0.22268390600565538 0.1958743085433313

# %% [markdown]
# # 4. Black Box 2: knowledge of training data and optimizer

# %%
for i, path in enumerate(path_list):
    
    # Read in config containing the paramters for the i-th model
    model_config_path = os.path.join(old_result_path, path, "params.json")
    config_model = json.load(open(model_config_path, ))
    
    # Only read in models that have a different initialization and activation function and optimizer
    if config_model["model::nlin"] == source_config["model::nlin"]:
        continue
    elif config_model["model::init_type"] == source_config["model::init_type"]:
        continue
    elif config_model["optim::optimizer"] != source_config["optim::optimizer"]:
        continue
    
    # Define model and load in state
    model = ConvNetSmall(
        channels_in=config_model["model::channels_in"],
        nlin=config_model["model::nlin"],
        dropout=config_model["model::dropout"],
        init_type=config_model["model::init_type"]
    )
    try:
        model.load_state_dict(
            torch.load(os.path.join(old_result_path, path, "checkpoint_000050", "checkpoints"))
        )
    except RuntimeError:
        model = ConvNetSmall(
            channels_in=config_model["model::channels_in"],
            nlin=config_model["model::nlin"],
            dropout=0,
            init_type=config_model["model::init_type"]
        )
        model.load_state_dict(
            torch.load(os.path.join(old_result_path, path, "checkpoint_000050", "checkpoints"))
        )
    model.to(config["device"])
    break
